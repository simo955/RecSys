# %%
from SLIM_BPR.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender

from MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_BPR_Cython, MatrixFactorization_FunkSVD_Cython
from MatrixFactorization.PureSVD import PureSVDRecommender

from Base.NonPersonalizedRecommender import TopPop, Random

from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender

from KNN.ItemKNNScoresHybridRecommender import ItemKNNScoresHybridRecommender
from KNN.ItemKNNScoresHybridRecommender3 import ItemKNNScoresHybridRecommender3

from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.ItemKNNSimilarityHybridRecommender3 import ItemKNNSimilarityHybridRecommender3
from KNN.ItemKNNSimilarityHybridRecommender4 import ItemKNNSimilarityHybridRecommender4

from KNN.UserKNNCBF1Recommender import UserKNNCBF1Recommender
from KNN.UserKNNCBFRecommender import UserKNNCBFRecommender


#from GraphBased.RP3betaRecommender import RP3betaRecommender
#from GraphBased.P3alphaRecommender import P3alphaRecommender

# %%
import traceback, os
import scipy.sparse
import pandas as pd
import numpy as np

URM_all = scipy.sparse.load_npz('./Matrix/URM_all_matrix.npz')
ICM_all = scipy.sparse.load_npz('./Matrix/ICM_all_matrix.npz')
URM_train = scipy.sparse.load_npz('./Matrix/URM_train_matrix.npz')
URM_test = scipy.sparse.load_npz('./Matrix/URM_test_matrix.npz')
UCM_all = scipy.sparse.load_npz('./Matrix/UCM_all_matrix.npz')

#Load playlistsIDS
train_df= pd.read_csv('all/train.csv',low_memory = False)
all_userID=train_df.playlist_id.unique()

# %%
CFrecommender = ItemKNNCFRecommender(URM_train) 
CFrecommender.fit()
SLIMrecommender = SLIM_BPR_Cython(URM_train) 
SLIMrecommender.fit()
CBFrecommender = ItemKNNCBFRecommender(ICM_all,URM_train) 
CBFrecommender.fit()
SLIMErecommender = SLIMElasticNetRecommender(URM_train) 
SLIMErecommender.fit()
UCFRecommender = UserKNNCFRecommender(URM_train)
UCFRecommender.fit()
# Out:
# Similarity column 20635 ( 100 % ), 3568.92 column/sec, elapsed time 0.10 min
# SLIM_BPR_Cython: Estimated memory required for similarity matrix of 20635 items is 1703.21 MB
# Processed 1165777 ( 100.00% ) in 6.87 seconds. BPR loss is 9.42E-01. Sample per second: 169805
# SLIM_BPR_Recommender: Epoch 1 of 100. Elapsed time 0.31 min
# Processed 1165777 ( 100.00% ) in 7.20 seconds. BPR loss is 2.13E+00. Sample per second: 161971
# SLIM_BPR_Recommender: Epoch 2 of 100. Elapsed time 0.41 min
# Processed 1165777 ( 100.00% ) in 5.80 seconds. BPR loss is 2.96E+00. Sample per second: 201096
# SLIM_BPR_Recommender: Epoch 3 of 100. Elapsed time 0.51 min
# Processed 1165777 ( 100.00% ) in 7.14 seconds. BPR loss is 3.66E+00. Sample per second: 163284
# SLIM_BPR_Recommender: Epoch 4 of 100. Elapsed time 0.61 min
# Processed 1165777 ( 100.00% ) in 5.81 seconds. BPR loss is 4.24E+00. Sample per second: 200720
# SLIM_BPR_Recommender: Epoch 5 of 100. Elapsed time 0.71 min
# Processed 1165777 ( 100.00% ) in 6.65 seconds. BPR loss is 4.76E+00. Sample per second: 175201
# SLIM_BPR_Recommender: Epoch 6 of 100. Elapsed time 0.81 min
# Processed 1165777 ( 100.00% ) in 5.96 seconds. BPR loss is 5.24E+00. Sample per second: 195667
# SLIM_BPR_Recommender: Epoch 7 of 100. Elapsed time 0.89 min
# Processed 1165777 ( 100.00% ) in 6.68 seconds. BPR loss is 5.69E+00. Sample per second: 174539
# SLIM_BPR_Recommender: Epoch 8 of 100. Elapsed time 0.99 min
# Processed 1165777 ( 100.00% ) in 6.56 seconds. BPR loss is 6.09E+00. Sample per second: 177714
# SLIM_BPR_Recommender: Epoch 9 of 100. Elapsed time 1.09 min
# Processed 1165777 ( 100.00% ) in 6.85 seconds. BPR loss is 6.47E+00. Sample per second: 170245
# SLIM_BPR_Recommender: Epoch 10 of 100. Elapsed time 1.19 min
# Processed 1165777 ( 100.00% ) in 6.84 seconds. BPR loss is 6.83E+00. Sample per second: 170415
# SLIM_BPR_Recommender: Epoch 11 of 100. Elapsed time 1.29 min
# Processed 1165777 ( 100.00% ) in 6.77 seconds. BPR loss is 7.14E+00. Sample per second: 172302
# SLIM_BPR_Recommender: Epoch 12 of 100. Elapsed time 1.39 min
# Processed 1165777 ( 100.00% ) in 7.89 seconds. BPR loss is 7.45E+00. Sample per second: 147680
# SLIM_BPR_Recommender: Epoch 13 of 100. Elapsed time 1.51 min
# Processed 1165777 ( 100.00% ) in 7.28 seconds. BPR loss is 7.79E+00. Sample per second: 160229
# SLIM_BPR_Recommender: Epoch 14 of 100. Elapsed time 1.62 min
# Processed 1165777 ( 100.00% ) in 6.38 seconds. BPR loss is 8.09E+00. Sample per second: 182652
# SLIM_BPR_Recommender: Epoch 15 of 100. Elapsed time 1.72 min
# Processed 1165777 ( 100.00% ) in 7.14 seconds. BPR loss is 8.34E+00. Sample per second: 163288
# SLIM_BPR_Recommender: Epoch 16 of 100. Elapsed time 1.83 min
# Processed 1165777 ( 100.00% ) in 6.37 seconds. BPR loss is 8.65E+00. Sample per second: 183148
# SLIM_BPR_Recommender: Epoch 17 of 100. Elapsed time 1.93 min
# Processed 1165777 ( 100.00% ) in 5.94 seconds. BPR loss is 8.89E+00. Sample per second: 196268
# SLIM_BPR_Recommender: Epoch 18 of 100. Elapsed time 2.03 min
# Processed 1165777 ( 100.00% ) in 6.96 seconds. BPR loss is 9.16E+00. Sample per second: 167525
# SLIM_BPR_Recommender: Epoch 19 of 100. Elapsed time 2.13 min
# Processed 1165777 ( 100.00% ) in 6.46 seconds. BPR loss is 9.39E+00. Sample per second: 180389
# SLIM_BPR_Recommender: Epoch 20 of 100. Elapsed time 2.22 min
# Processed 1165777 ( 100.00% ) in 6.63 seconds. BPR loss is 9.60E+00. Sample per second: 175785
# SLIM_BPR_Recommender: Epoch 21 of 100. Elapsed time 2.32 min
# Processed 1165777 ( 100.00% ) in 6.52 seconds. BPR loss is 9.84E+00. Sample per second: 178703
# SLIM_BPR_Recommender: Epoch 22 of 100. Elapsed time 2.42 min
# Processed 1165777 ( 100.00% ) in 5.52 seconds. BPR loss is 1.01E+01. Sample per second: 211069
# SLIM_BPR_Recommender: Epoch 23 of 100. Elapsed time 2.50 min
# Processed 1165777 ( 100.00% ) in 6.38 seconds. BPR loss is 1.03E+01. Sample per second: 182594
# SLIM_BPR_Recommender: Epoch 24 of 100. Elapsed time 2.60 min
# Processed 1165777 ( 100.00% ) in 5.78 seconds. BPR loss is 1.05E+01. Sample per second: 201833
# SLIM_BPR_Recommender: Epoch 25 of 100. Elapsed time 2.69 min
# Processed 1165777 ( 100.00% ) in 6.42 seconds. BPR loss is 1.07E+01. Sample per second: 181712
# SLIM_BPR_Recommender: Epoch 26 of 100. Elapsed time 2.78 min
# Processed 1165777 ( 100.00% ) in 5.47 seconds. BPR loss is 1.09E+01. Sample per second: 213030
# SLIM_BPR_Recommender: Epoch 27 of 100. Elapsed time 2.87 min
# Processed 1165777 ( 100.00% ) in 6.01 seconds. BPR loss is 1.11E+01. Sample per second: 194105
# SLIM_BPR_Recommender: Epoch 28 of 100. Elapsed time 2.96 min
# Processed 1165777 ( 100.00% ) in 5.73 seconds. BPR loss is 1.13E+01. Sample per second: 203603
# SLIM_BPR_Recommender: Epoch 29 of 100. Elapsed time 3.06 min
# Processed 1165777 ( 100.00% ) in 6.52 seconds. BPR loss is 1.14E+01. Sample per second: 178770
# SLIM_BPR_Recommender: Epoch 30 of 100. Elapsed time 3.15 min
# Processed 1165777 ( 100.00% ) in 6.21 seconds. BPR loss is 1.16E+01. Sample per second: 187831
# SLIM_BPR_Recommender: Epoch 31 of 100. Elapsed time 3.25 min
# Processed 1165777 ( 100.00% ) in 6.23 seconds. BPR loss is 1.18E+01. Sample per second: 187243
# SLIM_BPR_Recommender: Epoch 32 of 100. Elapsed time 3.35 min
# Processed 1165777 ( 100.00% ) in 5.63 seconds. BPR loss is 1.20E+01. Sample per second: 207181
# SLIM_BPR_Recommender: Epoch 33 of 100. Elapsed time 3.44 min
# Processed 1165777 ( 100.00% ) in 6.41 seconds. BPR loss is 1.22E+01. Sample per second: 181825
# SLIM_BPR_Recommender: Epoch 34 of 100. Elapsed time 3.53 min
# Processed 1165777 ( 100.00% ) in 10.73 seconds. BPR loss is 1.23E+01. Sample per second: 108631
# SLIM_BPR_Recommender: Epoch 35 of 100. Elapsed time 3.71 min
# Processed 1165777 ( 100.00% ) in 6.70 seconds. BPR loss is 1.25E+01. Sample per second: 173905
# SLIM_BPR_Recommender: Epoch 36 of 100. Elapsed time 3.81 min
# Processed 1165777 ( 100.00% ) in 6.42 seconds. BPR loss is 1.26E+01. Sample per second: 181699
# SLIM_BPR_Recommender: Epoch 37 of 100. Elapsed time 3.90 min
# Processed 1165777 ( 100.00% ) in 5.33 seconds. BPR loss is 1.28E+01. Sample per second: 218921
# SLIM_BPR_Recommender: Epoch 38 of 100. Elapsed time 3.98 min
# Processed 1165777 ( 100.00% ) in 5.04 seconds. BPR loss is 1.29E+01. Sample per second: 231115
# SLIM_BPR_Recommender: Epoch 39 of 100. Elapsed time 4.06 min
# Processed 1165777 ( 100.00% ) in 4.95 seconds. BPR loss is 1.31E+01. Sample per second: 235701
# SLIM_BPR_Recommender: Epoch 40 of 100. Elapsed time 4.14 min
# Processed 1165777 ( 100.00% ) in 5.68 seconds. BPR loss is 1.32E+01. Sample per second: 205087
# SLIM_BPR_Recommender: Epoch 41 of 100. Elapsed time 4.22 min
# Processed 1165777 ( 100.00% ) in 5.35 seconds. BPR loss is 1.34E+01. Sample per second: 218035
# SLIM_BPR_Recommender: Epoch 42 of 100. Elapsed time 4.30 min
# Processed 1165777 ( 100.00% ) in 5.04 seconds. BPR loss is 1.35E+01. Sample per second: 231246
# SLIM_BPR_Recommender: Epoch 43 of 100. Elapsed time 4.38 min
# Processed 1165777 ( 100.00% ) in 4.50 seconds. BPR loss is 1.37E+01. Sample per second: 259028
# SLIM_BPR_Recommender: Epoch 44 of 100. Elapsed time 4.45 min
# Processed 1165777 ( 100.00% ) in 5.38 seconds. BPR loss is 1.39E+01. Sample per second: 216612
# SLIM_BPR_Recommender: Epoch 45 of 100. Elapsed time 4.53 min
# Processed 1165777 ( 100.00% ) in 5.49 seconds. BPR loss is 1.40E+01. Sample per second: 212318
# SLIM_BPR_Recommender: Epoch 46 of 100. Elapsed time 4.62 min
# Processed 1165777 ( 100.00% ) in 5.88 seconds. BPR loss is 1.41E+01. Sample per second: 198107
# SLIM_BPR_Recommender: Epoch 47 of 100. Elapsed time 4.71 min
# Processed 1165777 ( 100.00% ) in 5.91 seconds. BPR loss is 1.42E+01. Sample per second: 197418
# SLIM_BPR_Recommender: Epoch 48 of 100. Elapsed time 4.79 min
# Processed 1165777 ( 100.00% ) in 5.54 seconds. BPR loss is 1.44E+01. Sample per second: 210598
# SLIM_BPR_Recommender: Epoch 49 of 100. Elapsed time 4.87 min
# Processed 1165777 ( 100.00% ) in 5.68 seconds. BPR loss is 1.45E+01. Sample per second: 205225
# SLIM_BPR_Recommender: Epoch 50 of 100. Elapsed time 4.96 min
# Processed 1165777 ( 100.00% ) in 5.86 seconds. BPR loss is 1.46E+01. Sample per second: 199074
# SLIM_BPR_Recommender: Epoch 51 of 100. Elapsed time 5.04 min
# Processed 1165777 ( 100.00% ) in 5.44 seconds. BPR loss is 1.48E+01. Sample per second: 214444
# SLIM_BPR_Recommender: Epoch 52 of 100. Elapsed time 5.12 min
# Processed 1165777 ( 100.00% ) in 5.13 seconds. BPR loss is 1.49E+01. Sample per second: 227339
# SLIM_BPR_Recommender: Epoch 53 of 100. Elapsed time 5.20 min
# Processed 1165777 ( 100.00% ) in 4.93 seconds. BPR loss is 1.49E+01. Sample per second: 236566
# SLIM_BPR_Recommender: Epoch 54 of 100. Elapsed time 5.28 min
# Processed 1165777 ( 100.00% ) in 6.01 seconds. BPR loss is 1.51E+01. Sample per second: 194107
# SLIM_BPR_Recommender: Epoch 55 of 100. Elapsed time 5.36 min
# Processed 1165777 ( 100.00% ) in 5.27 seconds. BPR loss is 1.52E+01. Sample per second: 221017
# SLIM_BPR_Recommender: Epoch 56 of 100. Elapsed time 5.45 min
# Processed 1165777 ( 100.00% ) in 5.93 seconds. BPR loss is 1.54E+01. Sample per second: 196443
# SLIM_BPR_Recommender: Epoch 57 of 100. Elapsed time 5.54 min
# Processed 1165777 ( 100.00% ) in 6.30 seconds. BPR loss is 1.55E+01. Sample per second: 184978
# SLIM_BPR_Recommender: Epoch 58 of 100. Elapsed time 5.63 min
# Processed 1165777 ( 100.00% ) in 5.84 seconds. BPR loss is 1.56E+01. Sample per second: 199740
# SLIM_BPR_Recommender: Epoch 59 of 100. Elapsed time 5.73 min
# Processed 1165777 ( 100.00% ) in 6.32 seconds. BPR loss is 1.56E+01. Sample per second: 184412
# SLIM_BPR_Recommender: Epoch 60 of 100. Elapsed time 5.82 min
# Processed 1165777 ( 100.00% ) in 6.03 seconds. BPR loss is 1.58E+01. Sample per second: 193365
# SLIM_BPR_Recommender: Epoch 61 of 100. Elapsed time 5.91 min
# Processed 1165777 ( 100.00% ) in 6.04 seconds. BPR loss is 1.59E+01. Sample per second: 192914
# SLIM_BPR_Recommender: Epoch 62 of 100. Elapsed time 6.01 min
# Processed 1165777 ( 100.00% ) in 4.75 seconds. BPR loss is 1.60E+01. Sample per second: 245247
# SLIM_BPR_Recommender: Epoch 63 of 100. Elapsed time 6.09 min
# Processed 1165777 ( 100.00% ) in 5.60 seconds. BPR loss is 1.61E+01. Sample per second: 208072
# SLIM_BPR_Recommender: Epoch 64 of 100. Elapsed time 6.17 min
# Processed 1165777 ( 100.00% ) in 5.26 seconds. BPR loss is 1.62E+01. Sample per second: 221711
# SLIM_BPR_Recommender: Epoch 65 of 100. Elapsed time 6.25 min
# Processed 1165777 ( 100.00% ) in 5.09 seconds. BPR loss is 1.63E+01. Sample per second: 229197
# SLIM_BPR_Recommender: Epoch 66 of 100. Elapsed time 6.33 min
# Processed 1165777 ( 100.00% ) in 5.31 seconds. BPR loss is 1.64E+01. Sample per second: 219640
# SLIM_BPR_Recommender: Epoch 67 of 100. Elapsed time 6.42 min
# Processed 1165777 ( 100.00% ) in 5.66 seconds. BPR loss is 1.66E+01. Sample per second: 205933
# SLIM_BPR_Recommender: Epoch 68 of 100. Elapsed time 6.51 min
# Processed 1165777 ( 100.00% ) in 6.22 seconds. BPR loss is 1.66E+01. Sample per second: 187302
# SLIM_BPR_Recommender: Epoch 69 of 100. Elapsed time 6.60 min
# Processed 1165777 ( 100.00% ) in 5.71 seconds. BPR loss is 1.67E+01. Sample per second: 203994
# SLIM_BPR_Recommender: Epoch 70 of 100. Elapsed time 6.69 min
# Processed 1165777 ( 100.00% ) in 6.63 seconds. BPR loss is 1.68E+01. Sample per second: 175824
# SLIM_BPR_Recommender: Epoch 71 of 100. Elapsed time 6.79 min
# Processed 1165777 ( 100.00% ) in 5.95 seconds. BPR loss is 1.69E+01. Sample per second: 195876
# SLIM_BPR_Recommender: Epoch 72 of 100. Elapsed time 6.88 min
# Processed 1165777 ( 100.00% ) in 6.04 seconds. BPR loss is 1.70E+01. Sample per second: 192888
# SLIM_BPR_Recommender: Epoch 73 of 100. Elapsed time 6.96 min
# Processed 1165777 ( 100.00% ) in 5.00 seconds. BPR loss is 1.71E+01. Sample per second: 233296
# SLIM_BPR_Recommender: Epoch 74 of 100. Elapsed time 7.04 min
# Processed 1165777 ( 100.00% ) in 7.60 seconds. BPR loss is 1.72E+01. Sample per second: 153310
# SLIM_BPR_Recommender: Epoch 75 of 100. Elapsed time 7.15 min
# Processed 1165777 ( 100.00% ) in 6.28 seconds. BPR loss is 1.73E+01. Sample per second: 185528
# SLIM_BPR_Recommender: Epoch 76 of 100. Elapsed time 7.25 min
# Processed 1165777 ( 100.00% ) in 6.68 seconds. BPR loss is 1.74E+01. Sample per second: 174530
# SLIM_BPR_Recommender: Epoch 77 of 100. Elapsed time 7.36 min
# Processed 1165777 ( 100.00% ) in 7.71 seconds. BPR loss is 1.75E+01. Sample per second: 151258
# SLIM_BPR_Recommender: Epoch 78 of 100. Elapsed time 7.47 min
# Processed 1165777 ( 100.00% ) in 6.82 seconds. BPR loss is 1.76E+01. Sample per second: 170996
# SLIM_BPR_Recommender: Epoch 79 of 100. Elapsed time 7.58 min
# Processed 1165777 ( 100.00% ) in 6.57 seconds. BPR loss is 1.77E+01. Sample per second: 177426
# SLIM_BPR_Recommender: Epoch 80 of 100. Elapsed time 7.67 min
# Processed 1165777 ( 100.00% ) in 7.09 seconds. BPR loss is 1.77E+01. Sample per second: 164347
# SLIM_BPR_Recommender: Epoch 81 of 100. Elapsed time 7.78 min
# Processed 1165777 ( 100.00% ) in 5.65 seconds. BPR loss is 1.78E+01. Sample per second: 206174
# SLIM_BPR_Recommender: Epoch 82 of 100. Elapsed time 7.87 min
# Processed 1165777 ( 100.00% ) in 6.44 seconds. BPR loss is 1.79E+01. Sample per second: 181050
# SLIM_BPR_Recommender: Epoch 83 of 100. Elapsed time 7.97 min
# Processed 1165777 ( 100.00% ) in 7.26 seconds. BPR loss is 1.80E+01. Sample per second: 160564
# SLIM_BPR_Recommender: Epoch 84 of 100. Elapsed time 8.08 min
# Processed 1165777 ( 100.00% ) in 6.67 seconds. BPR loss is 1.80E+01. Sample per second: 174781
# SLIM_BPR_Recommender: Epoch 85 of 100. Elapsed time 8.19 min
# Processed 1165777 ( 100.00% ) in 8.21 seconds. BPR loss is 1.81E+01. Sample per second: 142047
# SLIM_BPR_Recommender: Epoch 86 of 100. Elapsed time 8.31 min
# Processed 1165777 ( 100.00% ) in 6.89 seconds. BPR loss is 1.82E+01. Sample per second: 169258
# SLIM_BPR_Recommender: Epoch 87 of 100. Elapsed time 8.43 min
# Processed 1165777 ( 100.00% ) in 7.94 seconds. BPR loss is 1.84E+01. Sample per second: 146839
# SLIM_BPR_Recommender: Epoch 88 of 100. Elapsed time 8.54 min
# Processed 1165777 ( 100.00% ) in 6.38 seconds. BPR loss is 1.84E+01. Sample per second: 182760
# SLIM_BPR_Recommender: Epoch 89 of 100. Elapsed time 8.63 min
# Processed 1165777 ( 100.00% ) in 5.21 seconds. BPR loss is 1.85E+01. Sample per second: 223759
# SLIM_BPR_Recommender: Epoch 90 of 100. Elapsed time 8.71 min
# Processed 1165777 ( 100.00% ) in 4.74 seconds. BPR loss is 1.86E+01. Sample per second: 245784
# SLIM_BPR_Recommender: Epoch 91 of 100. Elapsed time 8.79 min
# Processed 1165777 ( 100.00% ) in 6.57 seconds. BPR loss is 1.86E+01. Sample per second: 177564
# SLIM_BPR_Recommender: Epoch 92 of 100. Elapsed time 8.89 min
# Processed 1165777 ( 100.00% ) in 5.93 seconds. BPR loss is 1.87E+01. Sample per second: 196683
# SLIM_BPR_Recommender: Epoch 93 of 100. Elapsed time 8.98 min
# Processed 1165777 ( 100.00% ) in 6.01 seconds. BPR loss is 1.88E+01. Sample per second: 194004
# SLIM_BPR_Recommender: Epoch 94 of 100. Elapsed time 9.06 min
# Processed 1165777 ( 100.00% ) in 5.34 seconds. BPR loss is 1.89E+01. Sample per second: 218113
# SLIM_BPR_Recommender: Epoch 95 of 100. Elapsed time 9.15 min
# Processed 1165777 ( 100.00% ) in 6.20 seconds. BPR loss is 1.89E+01. Sample per second: 187963
# SLIM_BPR_Recommender: Epoch 96 of 100. Elapsed time 9.25 min
# Processed 1165777 ( 100.00% ) in 5.95 seconds. BPR loss is 1.91E+01. Sample per second: 195842
# SLIM_BPR_Recommender: Epoch 97 of 100. Elapsed time 9.34 min
# Processed 1165777 ( 100.00% ) in 6.74 seconds. BPR loss is 1.91E+01. Sample per second: 172848
# SLIM_BPR_Recommender: Epoch 98 of 100. Elapsed time 9.44 min
# Processed 1165777 ( 100.00% ) in 6.39 seconds. BPR loss is 1.92E+01. Sample per second: 182460
# SLIM_BPR_Recommender: Epoch 99 of 100. Elapsed time 9.53 min
# Processed 1165777 ( 100.00% ) in 5.50 seconds. BPR loss is 1.93E+01. Sample per second: 212028
# SLIM_BPR_Recommender: Epoch 100 of 100. Elapsed time 9.62 min
# Similarity column 20635 ( 100 % ), 5682.99 column/sec, elapsed time 0.06 min
# Processed 3433 ( 16.64% ) in 5.00 minutes. Items per second: 11
# Processed 6767 ( 32.79% ) in 10.00 minutes. Items per second: 11
# Processed 10323 ( 50.03% ) in 15.00 minutes. Items per second: 11
# Processed 14161 ( 68.63% ) in 20.00 minutes. Items per second: 12
# Processed 18191 ( 88.16% ) in 25.00 minutes. Items per second: 12
# Processed 20635 ( 100.00% ) in 27.56 minutes. Items per second: 12
# Similarity column 47605 ( 94 % ), 1396.71 column/sec, elapsed time 0.57 min
# Similarity column 50446 ( 100 % ), 1399.18 column/sec, elapsed time 0.60 min

# %%
SuperSimilarity = ItemKNNSimilarityHybridRecommender(URM_train, SLIMrecommender, SLIMErecommender)
SuperSimilarity.fit(alpha=0.5, topK=600)

H3SimilaritySuper = ItemKNNSimilarityHybridRecommender3(URM_train, SuperSimilarity, CFrecommender,CBFrecommender)
H3SimilaritySuper.fit(topK=800, alpha=0.7, beta=0.4, gamma=0.2)

result = H3SimilaritySuper.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 9.28 seconds. Users per second: 1043
# Recommender MAP is= 0.09905309633537587

# %%
import pandas as pd
from numpy import *
import numpy as np
from scipy import sparse



data_playlists= pd.read_csv('all/train.csv',low_memory = False)
data_tracks= pd.read_csv('all/tracks.csv',low_memory = False)



#SPLITTAGGIO DEI DATI

#prendo il 20% delle random playlist da target playlist
target_playlist= pd.read_csv('all/target_playlists.csv',low_memory = False)
random_playlist=target_playlist.iloc[5000:10000]
random_id = random_playlist.playlist_id.values
random_data=data_playlists.loc[data_playlists['playlist_id'].isin(random_id)]
#random_data.shape = (114513, 2)
n=round((114513/100)*20)
random_subset = random_data.sample(n=n)

#prendo il 20% delle sequential playlist da target playlist
sequential_playlist=target_playlist.iloc[:5000]
sequential_id = sequential_playlist.playlist_id.values
sequential_data=data_playlists.loc[data_playlists['playlist_id'].isin(sequential_id)]
n1=round((115553/100)*20)
for pid in sequential_id:
    playlistID=sequential_data.loc[sequential_data['playlist_id']==pid]
    start=sequential_data.index[sequential_data['playlist_id'] == pid][0]
    end=start+round((playlistID.shape[0]*50)/100)

    dropping=list(range(start, end))    
    sequential_data=sequential_data.drop(dropping)


sequential_subset = sequential_data.sample(n=n1)

# %%
indexes=data_playlists.index.values
index_random=random_subset.index.values
index_sequential=sequential_subset.values

# %%
print(indexes.shape)
print(index_random.shape)
print(index_sequential.shape)
# Out:
# (1211791,)
# (22903,)
# (23111, 2)

# %%
data_playlists=data_playlists[~data_playlists.isin(sequential_subset)].dropna()
data_playlists=data_playlists[~data_playlists.isin(random_subset)].dropna()

# %%
data_playlists
# Out:
#          playlist_id  track_id
# 0                  0    14,301
# 1                  0     8,360
# 2                  0    12,844
# 3                  0    18,397
# 4                  0     1,220
# 5                  1    18,466
# 6                  1    16,782
# 7                  1     7,545
# 8                  1     8,248
# 9                  1    16,866
# 10                 1    12,393
# 11                 1    15,681
# 12                 1     5,630
# 13                 1    17,346
# 14                 1    12,909
# 15                 1     3,368
# 16                 1    20,315
# 17                 1    15,701
# 18                 1    11,112
# 19                 1    12,768
# 20                 1     3,373
# 21                 1    10,220
# 22                 1    11,496
# 23                 1    15,413
# 24                 1     8,506
# 25                 1    10,465
# 26                 1     2,018
# 27                 1     6,560
# 28                 1    20,500
# 29                 1    16,663
# ...              ...       ...
# 1211761       50,445    16,869
# 1211762       50,445    14,338
# 1211763       50,445    11,572
# 1211764       50,445    15,187
# 1211765       50,445    12,278
# 1211766       50,445     3,830
# 1211767       50,445    19,431
# 1211768       50,445     6,491
# 1211769       50,445    10,591
# 1211770       50,445     1,023
# 1211771       50,445     5,606
# 1211772       50,445    10,711
# 1211773       50,445     7,545
# 1211774       50,445    11,647
# 1211775       50,445     5,141
# 1211776       50,445    14,301
# 1211777       50,445     7,077
# 1211778       50,445     9,550
# 1211779       50,445     2,151
# 1211780       50,445     1,111
# 1211781       50,445     7,465
# 1211782       50,445    19,991
# 1211783       50,445     6,472
# 1211784       50,445    12,639
# 1211785       50,445     3,001
# 1211786       50,445    20,605
# 1211787       50,445     2,272
# 1211788       50,445        28
# 1211789       50,445     1,548
# 1211790       50,445     6,971
#
# [1165777 rows x 2 columns]

# %%
#CREAZIONE DELLA UCM_ALL

UCM_train=zeros((50446,19412))


#inizializzazione completa
for row in data_playlists.itertuples():
    riga = row.playlist_id
    #print(riga)
    track=data_tracks.loc[data_tracks['track_id'] == row.track_id]
    #print(colonna)
    UCM_train[riga,track.album_id]=1
    UCM_train[riga,12744+track.artist_id]=1

UCM_train=sparse.csr_matrix(UCM_train)   
sparse.save_npz('UCM_train_matrix.npz', UCM_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-ed05b5cf6974> in <module>()
#      11     track=data_tracks.loc[data_tracks['track_id'] == row.track_id]
#      12     #print(colonna)
# ---> 13     UCM_train[riga,track.album_id]=1
#      14     UCM_train[riga,12744+track.artist_id]=1
#      15
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
print(UCM_train.nnz)
print(UCM_all.nnz)

# %%
User1CBFrecommender = UserKNNCBF1Recommender(UCM_train,URM_train) 
User1CBFrecommender.fit(topK=200)


result = User1CBFrecommender.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# Similarity column 33399 ( 66 % ), 1013.22 column/sec, elapsed time 0.55 min
# Similarity column 50446 ( 100 % ), 995.95 column/sec, elapsed time 0.84 min
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 7.05 seconds. Users per second: 1372
# Recommender MAP is= 0.2671809750849438

# %%
User1CBFrecommender = UserKNNCBF1Recommender(UCM_all,URM_train) 
User1CBFrecommender.fit(topK=200)

result = User1CBFrecommender.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))

b=User1CBFrecommender.compute_item_score(all_userID)
print(b.shape)
# Out:
# Similarity column 24987 ( 50 % ), 829.82 column/sec, elapsed time 0.50 min
# Similarity column 49788 ( 99 % ), 797.72 column/sec, elapsed time 1.04 min
# Similarity column 50446 ( 100 % ), 792.44 column/sec, elapsed time 1.06 min
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 9.28 seconds. Users per second: 1043
# Recommender MAP is= 0.2671809750849438
# (50446, 20635)

# %%
from SLIM_BPR.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender

from MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_BPR_Cython, MatrixFactorization_FunkSVD_Cython
from MatrixFactorization.PureSVD import PureSVDRecommender

from Base.NonPersonalizedRecommender import TopPop, Random

from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender

from KNN.ItemKNNScoresHybridRecommender import ItemKNNScoresHybridRecommender
from KNN.ItemKNNScoresHybridRecommender3 import ItemKNNScoresHybridRecommender3

from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.ItemKNNSimilarityHybridRecommender3 import ItemKNNSimilarityHybridRecommender3
from KNN.ItemKNNSimilarityHybridRecommender4 import ItemKNNSimilarityHybridRecommender4

from KNN.UserKNNCBFRecommender import UserKNNCBFRecommender


#from GraphBased.RP3betaRecommender import RP3betaRecommender
from GraphBased.P3alphaRecommender import P3alphaRecommender

# %%
import traceback, os
import scipy.sparse
import pandas as pd
import numpy as np

URM_all = scipy.sparse.load_npz('./Matrix/URM_all_matrix.npz')
ICM_all = scipy.sparse.load_npz('./Matrix/ICM_all_matrix.npz')
URM_train = scipy.sparse.load_npz('./Matrix/URM_train_matrix.npz')
URM_test = scipy.sparse.load_npz('./Matrix/URM_test_matrix.npz')
UCM_all = scipy.sparse.load_npz('./Matrix/UCM_all_matrix.npz')
UCM_train = scipy.sparse.load_npz('UCM_train_matrix.npz')



#Load playlistsIDS
train_df= pd.read_csv('all/train.csv',low_memory = False)
all_userID=train_df.playlist_id.unique()

# %%
CFrecommender = ItemKNNCFRecommender(URM_train)
CFrecommender.fit()

SLIMrecommender = SLIM_BPR_Cython(URM_train)
SLIMrecommender.fit()

CBFrecommender = ItemKNNCBFRecommender(ICM_all,URM_train)
CBFrecommender.fit()

SLIMErecommender = SLIMElasticNetRecommender(URM_train)
SLIMErecommender.fit()

UCFRecommender = UserKNNCFRecommender(URM_train)
UCFRecommender.fit()
# Out:
# Similarity column 20635 ( 100 % ), 3602.02 column/sec, elapsed time 0.10 min
# SLIM_BPR_Cython: Estimated memory required for similarity matrix of 20635 items is 1703.21 MB
# Processed 1165777 ( 100.00% ) in 4.53 seconds. BPR loss is 9.42E-01. Sample per second: 257230
# SLIM_BPR_Recommender: Epoch 1 of 100. Elapsed time 0.20 min
# Processed 1165777 ( 100.00% ) in 4.84 seconds. BPR loss is 2.13E+00. Sample per second: 240901
# SLIM_BPR_Recommender: Epoch 2 of 100. Elapsed time 0.28 min
# Processed 1165777 ( 100.00% ) in 5.13 seconds. BPR loss is 2.96E+00. Sample per second: 227103
# SLIM_BPR_Recommender: Epoch 3 of 100. Elapsed time 0.35 min
# Processed 1165777 ( 100.00% ) in 4.19 seconds. BPR loss is 3.66E+00. Sample per second: 278428
# SLIM_BPR_Recommender: Epoch 4 of 100. Elapsed time 0.41 min
# Processed 1165777 ( 100.00% ) in 4.76 seconds. BPR loss is 4.24E+00. Sample per second: 244958
# SLIM_BPR_Recommender: Epoch 5 of 100. Elapsed time 0.49 min
# Processed 1165777 ( 100.00% ) in 5.30 seconds. BPR loss is 4.76E+00. Sample per second: 220029
# SLIM_BPR_Recommender: Epoch 6 of 100. Elapsed time 0.57 min
# Processed 1165777 ( 100.00% ) in 4.81 seconds. BPR loss is 5.24E+00. Sample per second: 242446
# SLIM_BPR_Recommender: Epoch 7 of 100. Elapsed time 0.64 min
# Processed 1165777 ( 100.00% ) in 5.34 seconds. BPR loss is 5.69E+00. Sample per second: 218295
# SLIM_BPR_Recommender: Epoch 8 of 100. Elapsed time 0.72 min
# Processed 1165777 ( 100.00% ) in 4.32 seconds. BPR loss is 6.09E+00. Sample per second: 269610
# SLIM_BPR_Recommender: Epoch 9 of 100. Elapsed time 0.78 min
# Processed 1165777 ( 100.00% ) in 4.35 seconds. BPR loss is 6.47E+00. Sample per second: 267981
# SLIM_BPR_Recommender: Epoch 10 of 100. Elapsed time 0.85 min
# Processed 1165777 ( 100.00% ) in 4.95 seconds. BPR loss is 6.83E+00. Sample per second: 235501
# SLIM_BPR_Recommender: Epoch 11 of 100. Elapsed time 0.93 min
# Processed 1165777 ( 100.00% ) in 5.01 seconds. BPR loss is 7.14E+00. Sample per second: 232844
# SLIM_BPR_Recommender: Epoch 12 of 100. Elapsed time 0.99 min
# Processed 1165777 ( 100.00% ) in 4.07 seconds. BPR loss is 7.45E+00. Sample per second: 286194
# SLIM_BPR_Recommender: Epoch 13 of 100. Elapsed time 1.06 min
# Processed 1165777 ( 100.00% ) in 4.60 seconds. BPR loss is 7.79E+00. Sample per second: 253490
# SLIM_BPR_Recommender: Epoch 14 of 100. Elapsed time 1.14 min
# Processed 1165777 ( 100.00% ) in 5.13 seconds. BPR loss is 8.09E+00. Sample per second: 227262
# SLIM_BPR_Recommender: Epoch 15 of 100. Elapsed time 1.21 min
# Processed 1165777 ( 100.00% ) in 4.65 seconds. BPR loss is 8.34E+00. Sample per second: 250787
# SLIM_BPR_Recommender: Epoch 16 of 100. Elapsed time 1.29 min
# Processed 1165777 ( 100.00% ) in 5.18 seconds. BPR loss is 8.65E+00. Sample per second: 225101
# SLIM_BPR_Recommender: Epoch 17 of 100. Elapsed time 1.36 min
# Processed 1165777 ( 100.00% ) in 4.90 seconds. BPR loss is 8.89E+00. Sample per second: 237845
# SLIM_BPR_Recommender: Epoch 18 of 100. Elapsed time 1.44 min
# Processed 1165777 ( 100.00% ) in 5.11 seconds. BPR loss is 9.16E+00. Sample per second: 228207
# SLIM_BPR_Recommender: Epoch 19 of 100. Elapsed time 1.51 min
# Processed 1165777 ( 100.00% ) in 4.66 seconds. BPR loss is 9.39E+00. Sample per second: 249935
# SLIM_BPR_Recommender: Epoch 20 of 100. Elapsed time 1.59 min
# Processed 1165777 ( 100.00% ) in 5.21 seconds. BPR loss is 9.60E+00. Sample per second: 223767
# SLIM_BPR_Recommender: Epoch 21 of 100. Elapsed time 1.66 min
# Processed 1165777 ( 100.00% ) in 4.62 seconds. BPR loss is 9.84E+00. Sample per second: 252111
# SLIM_BPR_Recommender: Epoch 22 of 100. Elapsed time 1.74 min
# Processed 1165777 ( 100.00% ) in 4.99 seconds. BPR loss is 1.01E+01. Sample per second: 233440
# SLIM_BPR_Recommender: Epoch 23 of 100. Elapsed time 1.81 min
# Processed 1165777 ( 100.00% ) in 5.53 seconds. BPR loss is 1.03E+01. Sample per second: 210813
# SLIM_BPR_Recommender: Epoch 24 of 100. Elapsed time 1.89 min
# Processed 1165777 ( 100.00% ) in 5.14 seconds. BPR loss is 1.05E+01. Sample per second: 226982
# SLIM_BPR_Recommender: Epoch 25 of 100. Elapsed time 1.96 min
# Processed 1165777 ( 100.00% ) in 4.69 seconds. BPR loss is 1.07E+01. Sample per second: 248771
# SLIM_BPR_Recommender: Epoch 26 of 100. Elapsed time 2.04 min
# Processed 1165777 ( 100.00% ) in 5.23 seconds. BPR loss is 1.09E+01. Sample per second: 222712
# SLIM_BPR_Recommender: Epoch 27 of 100. Elapsed time 2.12 min
# Processed 1165777 ( 100.00% ) in 4.76 seconds. BPR loss is 1.11E+01. Sample per second: 245091
# SLIM_BPR_Recommender: Epoch 28 of 100. Elapsed time 2.19 min
# Processed 1165777 ( 100.00% ) in 5.29 seconds. BPR loss is 1.13E+01. Sample per second: 220274
# SLIM_BPR_Recommender: Epoch 29 of 100. Elapsed time 2.27 min
# Processed 1165777 ( 100.00% ) in 4.82 seconds. BPR loss is 1.14E+01. Sample per second: 241772
# SLIM_BPR_Recommender: Epoch 30 of 100. Elapsed time 2.34 min
# Processed 1165777 ( 100.00% ) in 5.35 seconds. BPR loss is 1.16E+01. Sample per second: 218028
# SLIM_BPR_Recommender: Epoch 31 of 100. Elapsed time 2.42 min
# Processed 1165777 ( 100.00% ) in 4.85 seconds. BPR loss is 1.18E+01. Sample per second: 240185
# SLIM_BPR_Recommender: Epoch 32 of 100. Elapsed time 2.49 min
# Processed 1165777 ( 100.00% ) in 5.39 seconds. BPR loss is 1.20E+01. Sample per second: 216105
# SLIM_BPR_Recommender: Epoch 33 of 100. Elapsed time 2.57 min
# Processed 1165777 ( 100.00% ) in 4.92 seconds. BPR loss is 1.22E+01. Sample per second: 237072
# SLIM_BPR_Recommender: Epoch 34 of 100. Elapsed time 2.64 min
# Processed 1165777 ( 100.00% ) in 5.22 seconds. BPR loss is 1.23E+01. Sample per second: 223496
# SLIM_BPR_Recommender: Epoch 35 of 100. Elapsed time 2.72 min
# Processed 1165777 ( 100.00% ) in 3.78 seconds. BPR loss is 1.25E+01. Sample per second: 308662
# SLIM_BPR_Recommender: Epoch 36 of 100. Elapsed time 2.77 min
# Processed 1165777 ( 100.00% ) in 4.38 seconds. BPR loss is 1.26E+01. Sample per second: 266320
# SLIM_BPR_Recommender: Epoch 37 of 100. Elapsed time 2.83 min
# Processed 1165777 ( 100.00% ) in 3.93 seconds. BPR loss is 1.28E+01. Sample per second: 296389
# SLIM_BPR_Recommender: Epoch 38 of 100. Elapsed time 2.89 min
# Processed 1165777 ( 100.00% ) in 5.01 seconds. BPR loss is 1.29E+01. Sample per second: 232779
# SLIM_BPR_Recommender: Epoch 39 of 100. Elapsed time 2.96 min
# Processed 1165777 ( 100.00% ) in 4.53 seconds. BPR loss is 1.31E+01. Sample per second: 257126
# SLIM_BPR_Recommender: Epoch 40 of 100. Elapsed time 3.04 min
# Processed 1165777 ( 100.00% ) in 5.07 seconds. BPR loss is 1.32E+01. Sample per second: 229862
# SLIM_BPR_Recommender: Epoch 41 of 100. Elapsed time 3.11 min
# Processed 1165777 ( 100.00% ) in 4.60 seconds. BPR loss is 1.34E+01. Sample per second: 253384
# SLIM_BPR_Recommender: Epoch 42 of 100. Elapsed time 3.19 min
# Processed 1165777 ( 100.00% ) in 5.14 seconds. BPR loss is 1.35E+01. Sample per second: 226675
# SLIM_BPR_Recommender: Epoch 43 of 100. Elapsed time 3.26 min
# Processed 1165777 ( 100.00% ) in 4.68 seconds. BPR loss is 1.37E+01. Sample per second: 248835
# SLIM_BPR_Recommender: Epoch 44 of 100. Elapsed time 3.34 min
# Processed 1165777 ( 100.00% ) in 5.24 seconds. BPR loss is 1.39E+01. Sample per second: 222636
# SLIM_BPR_Recommender: Epoch 45 of 100. Elapsed time 3.42 min
# Processed 1165777 ( 100.00% ) in 4.92 seconds. BPR loss is 1.40E+01. Sample per second: 236927
# SLIM_BPR_Recommender: Epoch 46 of 100. Elapsed time 3.49 min
# Processed 1165777 ( 100.00% ) in 5.47 seconds. BPR loss is 1.41E+01. Sample per second: 213203
# SLIM_BPR_Recommender: Epoch 47 of 100. Elapsed time 3.57 min
# Processed 1165777 ( 100.00% ) in 4.98 seconds. BPR loss is 1.42E+01. Sample per second: 233905
# SLIM_BPR_Recommender: Epoch 48 of 100. Elapsed time 3.64 min
# Processed 1165777 ( 100.00% ) in 5.52 seconds. BPR loss is 1.44E+01. Sample per second: 211094
# SLIM_BPR_Recommender: Epoch 49 of 100. Elapsed time 3.72 min
# Processed 1165777 ( 100.00% ) in 5.05 seconds. BPR loss is 1.45E+01. Sample per second: 230790
# SLIM_BPR_Recommender: Epoch 50 of 100. Elapsed time 3.80 min
# Processed 1165777 ( 100.00% ) in 4.58 seconds. BPR loss is 1.46E+01. Sample per second: 254483
# SLIM_BPR_Recommender: Epoch 51 of 100. Elapsed time 3.87 min
# Processed 1165777 ( 100.00% ) in 5.10 seconds. BPR loss is 1.48E+01. Sample per second: 228370
# SLIM_BPR_Recommender: Epoch 52 of 100. Elapsed time 3.95 min
# Processed 1165777 ( 100.00% ) in 4.69 seconds. BPR loss is 1.49E+01. Sample per second: 248491
# SLIM_BPR_Recommender: Epoch 53 of 100. Elapsed time 4.02 min
# Processed 1165777 ( 100.00% ) in 5.26 seconds. BPR loss is 1.49E+01. Sample per second: 221798
# SLIM_BPR_Recommender: Epoch 54 of 100. Elapsed time 4.10 min
# Processed 1165777 ( 100.00% ) in 4.78 seconds. BPR loss is 1.51E+01. Sample per second: 243739
# SLIM_BPR_Recommender: Epoch 55 of 100. Elapsed time 4.17 min
# Processed 1165777 ( 100.00% ) in 5.33 seconds. BPR loss is 1.52E+01. Sample per second: 218816
# SLIM_BPR_Recommender: Epoch 56 of 100. Elapsed time 4.25 min
# Processed 1165777 ( 100.00% ) in 4.95 seconds. BPR loss is 1.54E+01. Sample per second: 235447
# SLIM_BPR_Recommender: Epoch 57 of 100. Elapsed time 4.33 min
# Processed 1165777 ( 100.00% ) in 5.49 seconds. BPR loss is 1.55E+01. Sample per second: 212330
# SLIM_BPR_Recommender: Epoch 58 of 100. Elapsed time 4.40 min
# Processed 1165777 ( 100.00% ) in 5.06 seconds. BPR loss is 1.56E+01. Sample per second: 230380
# SLIM_BPR_Recommender: Epoch 59 of 100. Elapsed time 4.48 min
# Processed 1165777 ( 100.00% ) in 4.62 seconds. BPR loss is 1.56E+01. Sample per second: 252514
# SLIM_BPR_Recommender: Epoch 60 of 100. Elapsed time 4.56 min
# Processed 1165777 ( 100.00% ) in 5.22 seconds. BPR loss is 1.58E+01. Sample per second: 223288
# SLIM_BPR_Recommender: Epoch 61 of 100. Elapsed time 4.63 min
# Processed 1165777 ( 100.00% ) in 4.73 seconds. BPR loss is 1.59E+01. Sample per second: 246209
# SLIM_BPR_Recommender: Epoch 62 of 100. Elapsed time 4.71 min
# Processed 1165777 ( 100.00% ) in 5.27 seconds. BPR loss is 1.60E+01. Sample per second: 221300
# SLIM_BPR_Recommender: Epoch 63 of 100. Elapsed time 4.78 min
# Processed 1165777 ( 100.00% ) in 4.79 seconds. BPR loss is 1.61E+01. Sample per second: 243133
# SLIM_BPR_Recommender: Epoch 64 of 100. Elapsed time 4.86 min
# Processed 1165777 ( 100.00% ) in 5.38 seconds. BPR loss is 1.62E+01. Sample per second: 216778
# SLIM_BPR_Recommender: Epoch 65 of 100. Elapsed time 4.93 min
# Processed 1165777 ( 100.00% ) in 4.96 seconds. BPR loss is 1.63E+01. Sample per second: 234937
# SLIM_BPR_Recommender: Epoch 66 of 100. Elapsed time 5.01 min
# Processed 1165777 ( 100.00% ) in 5.35 seconds. BPR loss is 1.64E+01. Sample per second: 217901
# SLIM_BPR_Recommender: Epoch 67 of 100. Elapsed time 5.08 min
# Processed 1165777 ( 100.00% ) in 3.95 seconds. BPR loss is 1.66E+01. Sample per second: 295189
# SLIM_BPR_Recommender: Epoch 68 of 100. Elapsed time 5.14 min
# Processed 1165777 ( 100.00% ) in 4.59 seconds. BPR loss is 1.66E+01. Sample per second: 254108
# SLIM_BPR_Recommender: Epoch 69 of 100. Elapsed time 5.20 min
# Processed 1165777 ( 100.00% ) in 4.16 seconds. BPR loss is 1.67E+01. Sample per second: 279957
# SLIM_BPR_Recommender: Epoch 70 of 100. Elapsed time 5.26 min
# Processed 1165777 ( 100.00% ) in 3.72 seconds. BPR loss is 1.68E+01. Sample per second: 313176
# SLIM_BPR_Recommender: Epoch 71 of 100. Elapsed time 5.32 min
# Processed 1165777 ( 100.00% ) in 4.35 seconds. BPR loss is 1.69E+01. Sample per second: 267902
# SLIM_BPR_Recommender: Epoch 72 of 100. Elapsed time 5.38 min
# Processed 1165777 ( 100.00% ) in 4.78 seconds. BPR loss is 1.70E+01. Sample per second: 243668
# SLIM_BPR_Recommender: Epoch 73 of 100. Elapsed time 5.46 min
# Processed 1165777 ( 100.00% ) in 5.40 seconds. BPR loss is 1.71E+01. Sample per second: 215876
# SLIM_BPR_Recommender: Epoch 74 of 100. Elapsed time 5.53 min
# Processed 1165777 ( 100.00% ) in 4.93 seconds. BPR loss is 1.72E+01. Sample per second: 236365
# SLIM_BPR_Recommender: Epoch 75 of 100. Elapsed time 5.61 min
# Processed 1165777 ( 100.00% ) in 5.47 seconds. BPR loss is 1.73E+01. Sample per second: 213224
# SLIM_BPR_Recommender: Epoch 76 of 100. Elapsed time 5.69 min
# Processed 1165777 ( 100.00% ) in 5.00 seconds. BPR loss is 1.74E+01. Sample per second: 233249
# SLIM_BPR_Recommender: Epoch 77 of 100. Elapsed time 5.76 min
# Processed 1165777 ( 100.00% ) in 4.69 seconds. BPR loss is 1.75E+01. Sample per second: 248771
# SLIM_BPR_Recommender: Epoch 78 of 100. Elapsed time 5.84 min
# Processed 1165777 ( 100.00% ) in 8.66 seconds. BPR loss is 1.76E+01. Sample per second: 134628
# SLIM_BPR_Recommender: Epoch 79 of 100. Elapsed time 5.97 min
# Processed 1165777 ( 100.00% ) in 5.99 seconds. BPR loss is 1.77E+01. Sample per second: 194606
# SLIM_BPR_Recommender: Epoch 80 of 100. Elapsed time 6.06 min
# Processed 1165777 ( 100.00% ) in 6.47 seconds. BPR loss is 1.77E+01. Sample per second: 180213
# SLIM_BPR_Recommender: Epoch 81 of 100. Elapsed time 6.15 min
# Processed 1165777 ( 100.00% ) in 5.38 seconds. BPR loss is 1.78E+01. Sample per second: 216820
# SLIM_BPR_Recommender: Epoch 82 of 100. Elapsed time 6.23 min
# Processed 1165777 ( 100.00% ) in 5.82 seconds. BPR loss is 1.79E+01. Sample per second: 200296
# SLIM_BPR_Recommender: Epoch 83 of 100. Elapsed time 6.33 min
# Processed 1165777 ( 100.00% ) in 5.13 seconds. BPR loss is 1.80E+01. Sample per second: 227280
# SLIM_BPR_Recommender: Epoch 84 of 100. Elapsed time 6.40 min
# Processed 1165777 ( 100.00% ) in 5.56 seconds. BPR loss is 1.80E+01. Sample per second: 209793
# SLIM_BPR_Recommender: Epoch 85 of 100. Elapsed time 6.49 min
# Processed 1165777 ( 100.00% ) in 5.90 seconds. BPR loss is 1.81E+01. Sample per second: 197611
# SLIM_BPR_Recommender: Epoch 86 of 100. Elapsed time 6.58 min
# Processed 1165777 ( 100.00% ) in 6.17 seconds. BPR loss is 1.82E+01. Sample per second: 188800
# SLIM_BPR_Recommender: Epoch 87 of 100. Elapsed time 6.66 min
# Processed 1165777 ( 100.00% ) in 5.55 seconds. BPR loss is 1.84E+01. Sample per second: 209940
# SLIM_BPR_Recommender: Epoch 88 of 100. Elapsed time 6.75 min
# Processed 1165777 ( 100.00% ) in 5.60 seconds. BPR loss is 1.84E+01. Sample per second: 208328
# SLIM_BPR_Recommender: Epoch 89 of 100. Elapsed time 6.84 min
# Processed 1165777 ( 100.00% ) in 4.78 seconds. BPR loss is 1.85E+01. Sample per second: 244073
# SLIM_BPR_Recommender: Epoch 90 of 100. Elapsed time 6.91 min
# Processed 1165777 ( 100.00% ) in 4.50 seconds. BPR loss is 1.86E+01. Sample per second: 258958
# SLIM_BPR_Recommender: Epoch 91 of 100. Elapsed time 6.97 min
# Processed 1165777 ( 100.00% ) in 5.67 seconds. BPR loss is 1.86E+01. Sample per second: 205738
# SLIM_BPR_Recommender: Epoch 92 of 100. Elapsed time 7.06 min
# Processed 1165777 ( 100.00% ) in 6.14 seconds. BPR loss is 1.87E+01. Sample per second: 189843
# SLIM_BPR_Recommender: Epoch 93 of 100. Elapsed time 7.15 min
# Processed 1165777 ( 100.00% ) in 5.76 seconds. BPR loss is 1.88E+01. Sample per second: 202223
# SLIM_BPR_Recommender: Epoch 94 of 100. Elapsed time 7.24 min
# Processed 1165777 ( 100.00% ) in 6.24 seconds. BPR loss is 1.89E+01. Sample per second: 186849
# SLIM_BPR_Recommender: Epoch 95 of 100. Elapsed time 7.33 min
# Processed 1165777 ( 100.00% ) in 5.53 seconds. BPR loss is 1.89E+01. Sample per second: 210808
# SLIM_BPR_Recommender: Epoch 96 of 100. Elapsed time 7.42 min
# Processed 1165777 ( 100.00% ) in 5.51 seconds. BPR loss is 1.91E+01. Sample per second: 211687
# SLIM_BPR_Recommender: Epoch 97 of 100. Elapsed time 7.50 min
# Processed 1165777 ( 100.00% ) in 5.30 seconds. BPR loss is 1.91E+01. Sample per second: 219877
# SLIM_BPR_Recommender: Epoch 98 of 100. Elapsed time 7.58 min
# Processed 1165777 ( 100.00% ) in 5.76 seconds. BPR loss is 1.92E+01. Sample per second: 202351
# SLIM_BPR_Recommender: Epoch 99 of 100. Elapsed time 7.67 min
# Processed 1165777 ( 100.00% ) in 6.29 seconds. BPR loss is 1.93E+01. Sample per second: 185484
# SLIM_BPR_Recommender: Epoch 100 of 100. Elapsed time 7.77 min
# Similarity column 20635 ( 100 % ), 6809.75 column/sec, elapsed time 0.05 min
# Processed 4292 ( 20.80% ) in 5.00 minutes. Items per second: 14
# Processed 8890 ( 43.08% ) in 10.00 minutes. Items per second: 15
# Processed 12869 ( 62.36% ) in 15.00 minutes. Items per second: 14
# Processed 16539 ( 80.15% ) in 20.00 minutes. Items per second: 14
# Processed 20390 ( 98.81% ) in 25.01 minutes. Items per second: 14
# Processed 20635 ( 100.00% ) in 25.34 minutes. Items per second: 14
# Similarity column 50446 ( 100 % ), 1261.21 column/sec, elapsed time 0.67 min

# %%
SVDrecommender = PureSVDRecommender (URM_train)
SVDrecommender.fit(num_factors=1000,n_iter=40)
result = SVDrecommender.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# PureSVDRecommender Computing SVD decomposition...
# PureSVDRecommender Computing SVD decomposition... Done!
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 9.55 seconds. Users per second: 1013
# Recommender MAP is= 0.05939999079263627

# %%
user_CBFrecommender = UserKNNCBF1Recommender(UCM_train,URM_train) 
user_CBFrecommender.fit()
result = user_CBFrecommender.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# Similarity column 47110 ( 93 % ), 837.33 column/sec, elapsed time 0.94 min
# Similarity column 50446 ( 100 % ), 841.13 column/sec, elapsed time 1.00 min
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 7.37 seconds. Users per second: 1313
# Recommender MAP is= 0.21955451966855466

# %%
p3Arecommender=P3alphaRecommender(URM_train)
p3Arecommender.fit()
result = p3Arecommender.evaluateRecommendations(URM_test)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 4.70 seconds. Users per second: 2058
# Recommender MAP is= 0.07859592796073765

# %%
Hrecommender=ItemKNNScoresHybridRecommender3(URM_train,UCFRecommender, p3Arecommender,SVDrecommender)
#alphaList = [(0.5, 0.5, 0.2), (0.5, 0.4, 0.1), (0.5, 0.5, 0.3), (0.5, 0.3, 0.1), (0.4, 0.3, 0.2), (0.4, 0.2, 0.2), (0.6, 0.2, 0.2), (0.5, 0.2, 0.2), (0.3, 0.5, 0.2), (0.3, 0.2, 0.2), (0.3, 0.3, 0.1)]
import random
for y in range(600):
    print("Iteration ={}".format(y))

    a = random.uniform(0.1, 0.9)
    b = random.uniform(0.1, 0.7)
    c = random.uniform(0.1, 0.5)

    print("a is= {} ,b is= {}, c is= {}".format(a,b,c))
    Hrecommender.fit(a,b,c)
    result = Hrecommender.evaluateRecommendations(URM_test)
    print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# Iteration =0
# a is= 0.7731940310673243 ,b is= 0.1989702160497017, c is= 0.3263626021883802
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.44 seconds. Users per second: 846
# Recommender MAP is= 0.07496060938920895
# Iteration =1
# a is= 0.745447599353333 ,b is= 0.25367649775296763, c is= 0.2586866509460846
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.49 seconds. Users per second: 775
# Recommender MAP is= 0.07814807943793615
# Iteration =2
# a is= 0.132864574288988 ,b is= 0.17501589076518098, c is= 0.12163566524100551
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.54 seconds. Users per second: 623
# Recommender MAP is= 0.07528758237674128
# Iteration =3
# a is= 0.1609980492011583 ,b is= 0.21824757857023347, c is= 0.2539546683227345
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.71 seconds. Users per second: 616
# Recommender MAP is= 0.07053061459491089
# Iteration =4
# a is= 0.3749004281584756 ,b is= 0.2979304118767982, c is= 0.10249444187488509
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.45 seconds. Users per second: 670
# Recommender MAP is= 0.08333281559814396
# Iteration =5
# a is= 0.38121321952564924 ,b is= 0.28227942006165535, c is= 0.4318334950886311
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.99 seconds. Users per second: 605
# Recommender MAP is= 0.07011810032297647
# Iteration =6
# a is= 0.11983489523719948 ,b is= 0.6846796642781914, c is= 0.18871826501690034
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.58 seconds. Users per second: 621
# Recommender MAP is= 0.07972704705590379
# Iteration =7
# a is= 0.2687636527342777 ,b is= 0.28120080085126364, c is= 0.2806855948778693
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.33 seconds. Users per second: 726
# Recommender MAP is= 0.07286856211353689
# Iteration =8
# a is= 0.711111918016365 ,b is= 0.11089268806053956, c is= 0.48780201457976136
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.86 seconds. Users per second: 752
# Recommender MAP is= 0.06942619654521287
# Iteration =9
# a is= 0.7366709924790954 ,b is= 0.6010660384283758, c is= 0.27547881937781793
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.95 seconds. Users per second: 647
# Recommender MAP is= 0.08095356032036613
# Iteration =10
# a is= 0.6020299525248509 ,b is= 0.12976463339992153, c is= 0.3801689618366988
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.65 seconds. Users per second: 661
# Recommender MAP is= 0.07101667919399339
# Iteration =11
# a is= 0.886459587326476 ,b is= 0.341921430168871, c is= 0.3168672480303639
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.03 seconds. Users per second: 644
# Recommender MAP is= 0.0782240129776435
# Iteration =12
# a is= 0.6344320548836161 ,b is= 0.25675678553822934, c is= 0.13513901625640867
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.86 seconds. Users per second: 698
# Recommender MAP is= 0.08293197425055018
# Iteration =13
# a is= 0.7211905437784435 ,b is= 0.3059224729473066, c is= 0.3980761081308891
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.62 seconds. Users per second: 662
# Recommender MAP is= 0.07445353233828703
# Iteration =14
# a is= 0.1409326860386238 ,b is= 0.23265998362448437, c is= 0.3098820009271934
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.17 seconds. Users per second: 638
# Recommender MAP is= 0.06900162024603453
# Iteration =15
# a is= 0.7683963768216742 ,b is= 0.6136047584170494, c is= 0.2990908280358156
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.89 seconds. Users per second: 650
# Recommender MAP is= 0.08047566203249303
# Iteration =16
# a is= 0.6784320238555994 ,b is= 0.5412054619884156, c is= 0.3958362360174571
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.40 seconds. Users per second: 628
# Recommender MAP is= 0.07672794678536954
# Iteration =17
# a is= 0.5635313520699413 ,b is= 0.3405649521630634, c is= 0.3137796807244785
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.62 seconds. Users per second: 662
# Recommender MAP is= 0.07574949960022433
# Iteration =18
# a is= 0.14567639637158242 ,b is= 0.5344009336748083, c is= 0.2734818131840555
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.84 seconds. Users per second: 611
# Recommender MAP is= 0.07539599512944499
# Iteration =19
# a is= 0.5186791142144587 ,b is= 0.23729761539493127, c is= 0.4410332939342675
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.97 seconds. Users per second: 646
# Recommender MAP is= 0.07068344599334388
# Iteration =20
# a is= 0.2435525436960142 ,b is= 0.4690257218357248, c is= 0.49590623170654324
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.07 seconds. Users per second: 688
# Recommender MAP is= 0.07047277540615257
# Iteration =21
# a is= 0.3515785159236836 ,b is= 0.3936336780253421, c is= 0.460687074615179
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 18.24 seconds. Users per second: 531
# Recommender MAP is= 0.07122195471133204
# Iteration =22
# a is= 0.4909702031550254 ,b is= 0.37212101536969655, c is= 0.15330708450941166
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 18.10 seconds. Users per second: 535
# Recommender MAP is= 0.08210897322753312
# Iteration =23
# a is= 0.27080856495067646 ,b is= 0.1679867374014174, c is= 0.2574718087828276
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.55 seconds. Users per second: 665
# Recommender MAP is= 0.07074292669217348
# Iteration =24
# a is= 0.8796234469833294 ,b is= 0.44970115494581775, c is= 0.2862606167652332
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.02 seconds. Users per second: 568
# Recommender MAP is= 0.07983918519752756
# Iteration =25
# a is= 0.6241467211388375 ,b is= 0.5582896179687639, c is= 0.23309520955650936
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.98 seconds. Users per second: 646
# Recommender MAP is= 0.08137121138857141
# Iteration =26
# a is= 0.6921620303077248 ,b is= 0.37130861661881975, c is= 0.38299534796497614
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 18.24 seconds. Users per second: 531
# Recommender MAP is= 0.07522278249524972
# Iteration =27
# a is= 0.7617331954808809 ,b is= 0.3294608613894152, c is= 0.19845552127119032
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.74 seconds. Users per second: 546
# Recommender MAP is= 0.08143506778218465
# Iteration =28
# a is= 0.7290259096729617 ,b is= 0.242616079619501, c is= 0.11755930905513426
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 19.27 seconds. Users per second: 502
# Recommender MAP is= 0.08423071903573487
# Iteration =29
# a is= 0.7642641360417342 ,b is= 0.6352253141973433, c is= 0.37492026100869436
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.19 seconds. Users per second: 563
# Recommender MAP is= 0.07842598939580422
# Iteration =30
# a is= 0.7505171931191547 ,b is= 0.22439592346797993, c is= 0.4369006909505667
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.86 seconds. Users per second: 574
# Recommender MAP is= 0.07244558883564448
# Iteration =31
# a is= 0.4442483297334795 ,b is= 0.10292114841408871, c is= 0.23432009143351695
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.87 seconds. Users per second: 697
# Recommender MAP is= 0.07240846994199364
# Iteration =32
# a is= 0.7037451210383389 ,b is= 0.6575177517480028, c is= 0.18671225146212125
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.71 seconds. Users per second: 616
# Recommender MAP is= 0.08393303303553143
# Iteration =33
# a is= 0.37425791846166445 ,b is= 0.4639959448557508, c is= 0.26840096269748204
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.70 seconds. Users per second: 579
# Recommender MAP is= 0.07706518584670381
# Iteration =34
# a is= 0.8044772004183621 ,b is= 0.3464715156287089, c is= 0.15043212592970479
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.44 seconds. Users per second: 670
# Recommender MAP is= 0.08372629028989743
# Iteration =35
# a is= 0.20591090974642157 ,b is= 0.2152835528300458, c is= 0.42818016818660576
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 18.29 seconds. Users per second: 529
# Recommender MAP is= 0.06722361774582918
# Iteration =36
# a is= 0.2209354589137642 ,b is= 0.19767177496134575, c is= 0.10313882152097356
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.69 seconds. Users per second: 617
# Recommender MAP is= 0.07921120037189297
# Iteration =37
# a is= 0.39366919905356634 ,b is= 0.5222924671153377, c is= 0.12312875930765262
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.00 seconds. Users per second: 745
# Recommender MAP is= 0.08390372524961158
# Iteration =38
# a is= 0.5454624166972634 ,b is= 0.4306664403836673, c is= 0.13381532492665144
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.70 seconds. Users per second: 762
# Recommender MAP is= 0.08391349694188478
# Iteration =39
# a is= 0.4232094381901298 ,b is= 0.1987072285437143, c is= 0.4159585053225904
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.91 seconds. Users per second: 696
# Recommender MAP is= 0.06951817232450849
# Iteration =40
# a is= 0.588918166279171 ,b is= 0.11729422498838085, c is= 0.2790504551415022
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.65 seconds. Users per second: 660
# Recommender MAP is= 0.07306304037928915
# Iteration =41
# a is= 0.8644540607901058 ,b is= 0.14055926676771077, c is= 0.1470798032653271
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.77 seconds. Users per second: 613
# Recommender MAP is= 0.08198444013474218
# Iteration =42
# a is= 0.5048223324361144 ,b is= 0.44482032826833684, c is= 0.26610716981191046
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.55 seconds. Users per second: 665
# Recommender MAP is= 0.07801165195975174
# Iteration =43
# a is= 0.24124759048650077 ,b is= 0.14338848855194816, c is= 0.1437949840610339
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.09 seconds. Users per second: 601
# Recommender MAP is= 0.0749701788078621
# Iteration =44
# a is= 0.6737118001157933 ,b is= 0.6192360138199641, c is= 0.3877460397166763
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.62 seconds. Users per second: 619
# Recommender MAP is= 0.07737399289251921
# Iteration =45
# a is= 0.8989654872109497 ,b is= 0.5550608046833158, c is= 0.3605342184977057
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.25 seconds. Users per second: 634
# Recommender MAP is= 0.07875213745393579
# Iteration =46
# a is= 0.8998432355521396 ,b is= 0.2615128639989958, c is= 0.4152631896149097
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.32 seconds. Users per second: 676
# Recommender MAP is= 0.07454602368828644
# Iteration =47
# a is= 0.3308925546437445 ,b is= 0.13310604913189167, c is= 0.2422750512981888
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.91 seconds. Users per second: 608
# Recommender MAP is= 0.07147444796113145
# Iteration =48
# a is= 0.41782004417029994 ,b is= 0.6565122869582429, c is= 0.3842408986561493
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.51 seconds. Users per second: 667
# Recommender MAP is= 0.07622612707466399
# Iteration =49
# a is= 0.254390259955305 ,b is= 0.5794929743096358, c is= 0.4336649506928638
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.01 seconds. Users per second: 744
# Recommender MAP is= 0.07335416619796596
# Iteration =50
# a is= 0.4818038524798396 ,b is= 0.6974010386373396, c is= 0.1363335159922442
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.82 seconds. Users per second: 700
# Recommender MAP is= 0.08408399547388815
# Iteration =51
# a is= 0.8556567558942066 ,b is= 0.10347638902136978, c is= 0.28110907812273267
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.90 seconds. Users per second: 750
# Recommender MAP is= 0.07530685033456372
# Iteration =52
# a is= 0.7312310866058435 ,b is= 0.5347432408710225, c is= 0.3185834484700708
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.27 seconds. Users per second: 678
# Recommender MAP is= 0.07895889823152479
# Iteration =53
# a is= 0.3960270835105638 ,b is= 0.2762065533717024, c is= 0.38619331589506933
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.31 seconds. Users per second: 727
# Recommender MAP is= 0.07123426524756102
# Iteration =54
# a is= 0.7642405761320518 ,b is= 0.6326077478273776, c is= 0.32039037444764584
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.92 seconds. Users per second: 648
# Recommender MAP is= 0.07988883008323283
# Iteration =55
# a is= 0.5479746546381498 ,b is= 0.13898795078798382, c is= 0.18188970847557695
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.81 seconds. Users per second: 653
# Recommender MAP is= 0.07728421697920666
# Iteration =56
# a is= 0.42712959864077193 ,b is= 0.4327726587684616, c is= 0.38747754177820226
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.68 seconds. Users per second: 617
# Recommender MAP is= 0.07405363908420688
# Iteration =57
# a is= 0.7219632177510572 ,b is= 0.15503112284011888, c is= 0.38108094197733555
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.66 seconds. Users per second: 581
# Recommender MAP is= 0.07218330203715001
# Iteration =58
# a is= 0.6909900473078777 ,b is= 0.10815669416786161, c is= 0.4797746638924917
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.81 seconds. Users per second: 701
# Recommender MAP is= 0.06931115109257771
# Iteration =59
# a is= 0.8700363263252572 ,b is= 0.6184178003368161, c is= 0.11102623306227032
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.29 seconds. Users per second: 728
# Recommender MAP is= 0.08605649936566581
# Iteration =60
# a is= 0.8690056066317289 ,b is= 0.2577988600180271, c is= 0.28659800015655446
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.86 seconds. Users per second: 574
# Recommender MAP is= 0.0781116717649577
# Iteration =61
# a is= 0.4492972166305187 ,b is= 0.5546494675246016, c is= 0.10820556967826489
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.26 seconds. Users per second: 679
# Recommender MAP is= 0.08443692365444641
# Iteration =62
# a is= 0.7030749662917949 ,b is= 0.551108827082161, c is= 0.2595080786179842
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.95 seconds. Users per second: 694
# Recommender MAP is= 0.08082168827064136
# Iteration =63
# a is= 0.49262598979561545 ,b is= 0.657212708127114, c is= 0.3486084985023977
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.21 seconds. Users per second: 681
# Recommender MAP is= 0.07747176205583951
# Iteration =64
# a is= 0.2357221817884023 ,b is= 0.29719820262392754, c is= 0.21318885419629813
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.08 seconds. Users per second: 740
# Recommender MAP is= 0.07516173632000833
# Iteration =65
# a is= 0.26249638284599125 ,b is= 0.44992054552074234, c is= 0.1254494735332793
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.51 seconds. Users per second: 716
# Recommender MAP is= 0.08209310478149129
# Iteration =66
# a is= 0.5617480964959922 ,b is= 0.4155772659486787, c is= 0.3900211870220377
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.77 seconds. Users per second: 614
# Recommender MAP is= 0.07468841658641474
# Iteration =67
# a is= 0.3518399478326385 ,b is= 0.44265672287395885, c is= 0.15595512848992
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.85 seconds. Users per second: 699
# Recommender MAP is= 0.08149430181102824
# Iteration =68
# a is= 0.24955792919078654 ,b is= 0.2187686008938466, c is= 0.3910578075849688
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.65 seconds. Users per second: 548
# Recommender MAP is= 0.06827536079273337
# Iteration =69
# a is= 0.7492864288216101 ,b is= 0.5792312781699561, c is= 0.43578836331210713
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.78 seconds. Users per second: 613
# Recommender MAP is= 0.07653892017530743
# Iteration =70
# a is= 0.464950286612248 ,b is= 0.5783506826288893, c is= 0.47668702615773206
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.62 seconds. Users per second: 662
# Recommender MAP is= 0.07409063549726704
# Iteration =71
# a is= 0.2594962187088079 ,b is= 0.21916063396627627, c is= 0.27647305773600894
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.35 seconds. Users per second: 725
# Recommender MAP is= 0.07157260809890245
# Iteration =72
# a is= 0.25420954534685136 ,b is= 0.6834047092935048, c is= 0.3011995913444907
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.85 seconds. Users per second: 698
# Recommender MAP is= 0.07737962447717721
# Iteration =73
# a is= 0.39274822334974857 ,b is= 0.1412840847507542, c is= 0.2984906075516093
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.36 seconds. Users per second: 558
# Recommender MAP is= 0.07075904058762682
# Iteration =74
# a is= 0.7846001516189255 ,b is= 0.15194424989363836, c is= 0.30256764830989213
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 20.85 seconds. Users per second: 464
# Recommender MAP is= 0.074975939692054
# Iteration =75
# a is= 0.7182393561483813 ,b is= 0.6591777403188619, c is= 0.4683271963378901
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.41 seconds. Users per second: 628
# Recommender MAP is= 0.07640097968914396
# Iteration =76
# a is= 0.6945722315522167 ,b is= 0.684549210214995, c is= 0.3630657736899411
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.17 seconds. Users per second: 683
# Recommender MAP is= 0.0786458169939081
# Iteration =77
# a is= 0.6123121951848578 ,b is= 0.3889924718282427, c is= 0.16496096446008524
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.95 seconds. Users per second: 693
# Recommender MAP is= 0.08263556689173163
# Iteration =78
# a is= 0.7147585037051897 ,b is= 0.5566578624130635, c is= 0.3829886766751551
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.58 seconds. Users per second: 551
# Recommender MAP is= 0.07721746238820583
# Iteration =79
# a is= 0.11780099498497272 ,b is= 0.6850780723292927, c is= 0.4268517756850948
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.41 seconds. Users per second: 556
# Recommender MAP is= 0.07313803881239678
# Iteration =80
# a is= 0.29694336908155555 ,b is= 0.46800487405515157, c is= 0.22432999502118608
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.60 seconds. Users per second: 712
# Recommender MAP is= 0.07790913803244257
# Iteration =81
# a is= 0.6507656049127374 ,b is= 0.6252265833000675, c is= 0.3339458353707406
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.10 seconds. Users per second: 739
# Recommender MAP is= 0.07874572084452854
# Iteration =82
# a is= 0.17447156742154882 ,b is= 0.47273934280375374, c is= 0.2326863047358403
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.78 seconds. Users per second: 757
# Recommender MAP is= 0.07632951120655396
# Iteration =83
# a is= 0.6585896871821223 ,b is= 0.37284010945832813, c is= 0.37180209487939353
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.39 seconds. Users per second: 723
# Recommender MAP is= 0.07525536225104315
# Iteration =84
# a is= 0.43035871066651055 ,b is= 0.3135006380499985, c is= 0.2260123972010126
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.72 seconds. Users per second: 705
# Recommender MAP is= 0.07715750940838416
# Iteration =85
# a is= 0.16168665985409927 ,b is= 0.4361225794328748, c is= 0.23520247517291
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.84 seconds. Users per second: 652
# Recommender MAP is= 0.0755785312772007
# Iteration =86
# a is= 0.10156255275873338 ,b is= 0.6860763756503939, c is= 0.33641798485583935
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.93 seconds. Users per second: 695
# Recommender MAP is= 0.0749075911608421
# Iteration =87
# a is= 0.8773249351236034 ,b is= 0.16127516595118147, c is= 0.345206982846837
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.26 seconds. Users per second: 678
# Recommender MAP is= 0.07444187887804193
# Iteration =88
# a is= 0.11170973444629713 ,b is= 0.18718870917931146, c is= 0.12242189619292852
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.35 seconds. Users per second: 674
# Recommender MAP is= 0.07508246061925133
# Iteration =89
# a is= 0.8106990947207626 ,b is= 0.6244636072139947, c is= 0.3520320965333237
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.96 seconds. Users per second: 606
# Recommender MAP is= 0.07921031906822099
# Iteration =90
# a is= 0.1985301312762439 ,b is= 0.371155132688716, c is= 0.14445328127571155
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 22.57 seconds. Users per second: 429
# Recommender MAP is= 0.07947976207922261
# Iteration =91
# a is= 0.17386777508459064 ,b is= 0.5399599598886677, c is= 0.2775560267217483
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 18.87 seconds. Users per second: 513
# Recommender MAP is= 0.07569186182254638
# Iteration =92
# a is= 0.6475016856532536 ,b is= 0.6173899091866769, c is= 0.10182844780521748
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.89 seconds. Users per second: 609
# Recommender MAP is= 0.08571163853212967
# Iteration =93
# a is= 0.5796926820180535 ,b is= 0.11614581677724922, c is= 0.2283360543310584
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.70 seconds. Users per second: 706
# Recommender MAP is= 0.07478262139528827
# Iteration =94
# a is= 0.1316509634079906 ,b is= 0.6139450764882864, c is= 0.450105306473638
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.06 seconds. Users per second: 802
# Recommender MAP is= 0.07225333608421546
# Iteration =95
# a is= 0.19695380262877818 ,b is= 0.4791671334950157, c is= 0.34397196027038657
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.67 seconds. Users per second: 763
# Recommender MAP is= 0.07355857766242
# Iteration =96
# a is= 0.7706531598679528 ,b is= 0.5956155794065957, c is= 0.1663560825826454
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.88 seconds. Users per second: 814
# Recommender MAP is= 0.08444757673176292
# Iteration =97
# a is= 0.6644549221910938 ,b is= 0.15794410142117024, c is= 0.4794661086843818
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.81 seconds. Users per second: 756
# Recommender MAP is= 0.07003364103725643
# Iteration =98
# a is= 0.45457868480861385 ,b is= 0.2060420731499289, c is= 0.4147314798193771
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.44 seconds. Users per second: 627
# Recommender MAP is= 0.06998954667378263
# Iteration =99
# a is= 0.30790415638052915 ,b is= 0.5460152659425749, c is= 0.13912488755906882
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.56 seconds. Users per second: 770
# Recommender MAP is= 0.08254346334268844
# Iteration =100
# a is= 0.13250898093332497 ,b is= 0.3633765123203698, c is= 0.4563240913085216
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.85 seconds. Users per second: 652
# Recommender MAP is= 0.06864126906791387
# Iteration =101
# a is= 0.4383713512820474 ,b is= 0.128856366076535, c is= 0.3843551696327866
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.26 seconds. Users per second: 679
# Recommender MAP is= 0.06904086090516937
# Iteration =102
# a is= 0.1229006384729698 ,b is= 0.527463688806367, c is= 0.33857836862231383
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.12 seconds. Users per second: 640
# Recommender MAP is= 0.07325006222000977
# Iteration =103
# a is= 0.6030068850215972 ,b is= 0.5439461146171736, c is= 0.1910024036259455
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.63 seconds. Users per second: 661
# Recommender MAP is= 0.08267791723314367
# Iteration =104
# a is= 0.678015382383828 ,b is= 0.6178196255450145, c is= 0.33932808394598357
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.72 seconds. Users per second: 705
# Recommender MAP is= 0.07873440587402708
# Iteration =105
# a is= 0.7821937736960157 ,b is= 0.6357281391946019, c is= 0.49193907352895727
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.68 seconds. Users per second: 707
# Recommender MAP is= 0.07619990438051244
# Iteration =106
# a is= 0.754478970874575 ,b is= 0.12642552490805, c is= 0.41877498107430366
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.16 seconds. Users per second: 599
# Recommender MAP is= 0.07125721839671366
# Iteration =107
# a is= 0.889923851294472 ,b is= 0.6336171472750012, c is= 0.4503782551863662
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.02 seconds. Users per second: 604
# Recommender MAP is= 0.07749235791743714
# Iteration =108
# a is= 0.8021508265849441 ,b is= 0.6059339216917415, c is= 0.16702580614513077
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.27 seconds. Users per second: 858
# Recommender MAP is= 0.08456319152548107
# Iteration =109
# a is= 0.5817497164156331 ,b is= 0.64420318408086, c is= 0.38879388264975256
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.21 seconds. Users per second: 863
# Recommender MAP is= 0.07709955612031359
# Iteration =110
# a is= 0.6144453713003644 ,b is= 0.4957586349233414, c is= 0.18922869641440992
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.75 seconds. Users per second: 704
# Recommender MAP is= 0.08239684899785563
# Iteration =111
# a is= 0.456323956878227 ,b is= 0.47793006957529505, c is= 0.1999188714000026
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.36 seconds. Users per second: 674
# Recommender MAP is= 0.08085528419546116
# Iteration =112
# a is= 0.5977771271521665 ,b is= 0.19437104660109433, c is= 0.49307849937626036
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.21 seconds. Users per second: 732
# Recommender MAP is= 0.06977837425141996
# Iteration =113
# a is= 0.3768539496168176 ,b is= 0.23886568549351356, c is= 0.33692391639683295
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.73 seconds. Users per second: 760
# Recommender MAP is= 0.07155540763168082
# Iteration =114
# a is= 0.7216707321457928 ,b is= 0.10118618091387153, c is= 0.2974858522213779
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.67 seconds. Users per second: 708
# Recommender MAP is= 0.07324490478789163
# Iteration =115
# a is= 0.5722170439837435 ,b is= 0.4970525074948502, c is= 0.2841336856637301
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.92 seconds. Users per second: 812
# Recommender MAP is= 0.07860196526438727
# Iteration =116
# a is= 0.7377022805174859 ,b is= 0.17600012058476688, c is= 0.20412400411927178
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.31 seconds. Users per second: 786
# Recommender MAP is= 0.07918977025570532
# Iteration =117
# a is= 0.23629280480154513 ,b is= 0.22732826750479673, c is= 0.44878077817740347
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.52 seconds. Users per second: 840
# Recommender MAP is= 0.06750875231720407
# Iteration =118
# a is= 0.47497375610285786 ,b is= 0.33966152675063355, c is= 0.3792978847423951
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.07 seconds. Users per second: 740
# Recommender MAP is= 0.07334569264372268
# Iteration =119
# a is= 0.4222519877561839 ,b is= 0.3440269920322252, c is= 0.3194050495240357
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.70 seconds. Users per second: 658
# Recommender MAP is= 0.07448424783728504
# Iteration =120
# a is= 0.46019887723939645 ,b is= 0.26030734949855533, c is= 0.13332317243069358
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.79 seconds. Users per second: 757
# Recommender MAP is= 0.08150057784279169
# Iteration =121
# a is= 0.6965309217858188 ,b is= 0.5696808988217429, c is= 0.32438891038149614
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.46 seconds. Users per second: 626
# Recommender MAP is= 0.07883380248639954
# Iteration =122
# a is= 0.3324981283258411 ,b is= 0.6664389025995595, c is= 0.4545655443462061
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.18 seconds. Users per second: 637
# Recommender MAP is= 0.07430031541730332
# Iteration =123
# a is= 0.323415093368783 ,b is= 0.3121489932468011, c is= 0.36768887976695763
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.58 seconds. Users per second: 713
# Recommender MAP is= 0.07165081648042083
# Iteration =124
# a is= 0.36559825246080035 ,b is= 0.5047244914684318, c is= 0.39481856742480514
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.68 seconds. Users per second: 659
# Recommender MAP is= 0.07414066627983239
# Iteration =125
# a is= 0.1496766194475864 ,b is= 0.24079676896711824, c is= 0.4109716599746799
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.02 seconds. Users per second: 690
# Recommender MAP is= 0.06729434260556007
# Iteration =126
# a is= 0.47550167030523605 ,b is= 0.6682189814285948, c is= 0.3681520204948273
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.29 seconds. Users per second: 857
# Recommender MAP is= 0.07691165092535547
# Iteration =127
# a is= 0.2871387571761469 ,b is= 0.523389383648295, c is= 0.37264824343914893
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.35 seconds. Users per second: 852
# Recommender MAP is= 0.07424308047806105
# Iteration =128
# a is= 0.3720386477829194 ,b is= 0.12079306412131159, c is= 0.39016876703622094
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.84 seconds. Users per second: 817
# Recommender MAP is= 0.06816018062121283
# Iteration =129
# a is= 0.117885044337066 ,b is= 0.4986266228860061, c is= 0.48144989796894955
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.79 seconds. Users per second: 821
# Recommender MAP is= 0.07002196674587197
# Iteration =130
# a is= 0.8029852809250837 ,b is= 0.37966150651531816, c is= 0.466275710983615
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.84 seconds. Users per second: 754
# Recommender MAP is= 0.07438344035461467
# Iteration =131
# a is= 0.8766478542095556 ,b is= 0.39733263330195856, c is= 0.35474830053242334
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.73 seconds. Users per second: 760
# Recommender MAP is= 0.07749792036875065
# Iteration =132
# a is= 0.7872491581373932 ,b is= 0.2984093242691634, c is= 0.29154836075051915
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.10 seconds. Users per second: 800
# Recommender MAP is= 0.07782998660245255
# Iteration =133
# a is= 0.5494217686233165 ,b is= 0.2008404129557686, c is= 0.3857637944108391
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.83 seconds. Users per second: 818
# Recommender MAP is= 0.07148442495404911
# Iteration =134
# a is= 0.25326440964420316 ,b is= 0.17938876792262848, c is= 0.49636359577807687
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.84 seconds. Users per second: 817
# Recommender MAP is= 0.06645789674194219
# Iteration =135
# a is= 0.8120673048873979 ,b is= 0.4628396176387515, c is= 0.1621094989727439
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.97 seconds. Users per second: 809
# Recommender MAP is= 0.08421788820924689
# Iteration =136
# a is= 0.31935433585242146 ,b is= 0.22510579657675114, c is= 0.22534449215573857
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.30 seconds. Users per second: 856
# Recommender MAP is= 0.07429369851974446
# Iteration =137
# a is= 0.14070651229374445 ,b is= 0.17845651020384323, c is= 0.34340364801533396
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.40 seconds. Users per second: 849
# Recommender MAP is= 0.06705721033571375
# Iteration =138
# a is= 0.24364766046124667 ,b is= 0.5109727920337284, c is= 0.14482743057616965
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.95 seconds. Users per second: 810
# Recommender MAP is= 0.08126647121459392
# Iteration =139
# a is= 0.6079644629199418 ,b is= 0.2228186537303922, c is= 0.25799180296467716
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.61 seconds. Users per second: 833
# Recommender MAP is= 0.07615104660267023
# Iteration =140
# a is= 0.4331602952456274 ,b is= 0.6932061206636164, c is= 0.49649840885254803
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.29 seconds. Users per second: 857
# Recommender MAP is= 0.07457866494476459
# Iteration =141
# a is= 0.6185269121283257 ,b is= 0.40997315512660537, c is= 0.12025586765261825
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.55 seconds. Users per second: 838
# Recommender MAP is= 0.08461381243144607
# Iteration =142
# a is= 0.15910083637341624 ,b is= 0.36578669005894426, c is= 0.2918018935776172
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.01 seconds. Users per second: 879
# Recommender MAP is= 0.07264356992261006
# Iteration =143
# a is= 0.1898134081390242 ,b is= 0.29587851597899434, c is= 0.22984902204875227
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 10.85 seconds. Users per second: 891
# Recommender MAP is= 0.07384370435702023
# Iteration =144
# a is= 0.8501991959471599 ,b is= 0.20166840131190544, c is= 0.4668399367350753
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.94 seconds. Users per second: 811
# Recommender MAP is= 0.07217048082878981
# Iteration =145
# a is= 0.5523124982565835 ,b is= 0.12523513267357853, c is= 0.2754574583935577
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.27 seconds. Users per second: 678
# Recommender MAP is= 0.07300410192478685
# Iteration =146
# a is= 0.7041480923270532 ,b is= 0.28303696154186747, c is= 0.2794745528319687
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.92 seconds. Users per second: 812
# Recommender MAP is= 0.07726988126562921
# Iteration =147
# a is= 0.22558018110721126 ,b is= 0.2981851388492513, c is= 0.36014473992005047
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.68 seconds. Users per second: 829
# Recommender MAP is= 0.0702363312474332
# Iteration =148
# a is= 0.742583087589121 ,b is= 0.257917873388807, c is= 0.3282564743693353
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.61 seconds. Users per second: 833
# Recommender MAP is= 0.07557286538625975
# Iteration =149
# a is= 0.21807204352230533 ,b is= 0.5482218991426329, c is= 0.4736051186429344
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.47 seconds. Users per second: 844
# Recommender MAP is= 0.07167922576070361
# Iteration =150
# a is= 0.3699498616742696 ,b is= 0.45463338652129637, c is= 0.4522268744732538
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.72 seconds. Users per second: 826
# Recommender MAP is= 0.0723236447117393
# Iteration =151
# a is= 0.22906527852207947 ,b is= 0.6831940614711597, c is= 0.39843090507630563
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.05 seconds. Users per second: 741
# Recommender MAP is= 0.07470832890997102
# Iteration =152
# a is= 0.22415883578066165 ,b is= 0.4829693615761871, c is= 0.11909536218745083
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.72 seconds. Users per second: 761
# Recommender MAP is= 0.0821699484141565
# Iteration =153
# a is= 0.8626112873875887 ,b is= 0.12409046022223068, c is= 0.2479319537116446
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.32 seconds. Users per second: 854
# Recommender MAP is= 0.07690085844214764
# Iteration =154
# a is= 0.16968001002125382 ,b is= 0.15399343966172524, c is= 0.3924282715368729
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.06 seconds. Users per second: 802
# Recommender MAP is= 0.06625879324713829
# Iteration =155
# a is= 0.8919014437465612 ,b is= 0.6073316236573951, c is= 0.2008227886172553
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.67 seconds. Users per second: 829
# Recommender MAP is= 0.08405527292906965
# Iteration =156
# a is= 0.895414886344612 ,b is= 0.3680827943625239, c is= 0.4068674333943172
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.78 seconds. Users per second: 821
# Recommender MAP is= 0.07598008381291817
# Iteration =157
# a is= 0.14489092821601268 ,b is= 0.5865006593968198, c is= 0.3164790179988025
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.61 seconds. Users per second: 833
# Recommender MAP is= 0.07473258071793148
# Iteration =158
# a is= 0.11948466307151451 ,b is= 0.29741666352234136, c is= 0.1340477658784409
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.70 seconds. Users per second: 827
# Recommender MAP is= 0.07742133865511637
# Iteration =159
# a is= 0.3838180081119176 ,b is= 0.4841155046168497, c is= 0.2258919492375291
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.37 seconds. Users per second: 851
# Recommender MAP is= 0.07901397657822172
# Iteration =160
# a is= 0.13723150226989667 ,b is= 0.6367792392074741, c is= 0.2781556714649958
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.35 seconds. Users per second: 725
# Recommender MAP is= 0.07654768671627378
# Iteration =161
# a is= 0.4823678337745013 ,b is= 0.16217707179931168, c is= 0.3663122892871371
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.17 seconds. Users per second: 795
# Recommender MAP is= 0.070553275912818
# Iteration =162
# a is= 0.15766591998785628 ,b is= 0.22268751707040296, c is= 0.13587396810078645
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.94 seconds. Users per second: 748
# Recommender MAP is= 0.07617788555679168
# Iteration =163
# a is= 0.8709479390840952 ,b is= 0.33346522615514707, c is= 0.43869668564165865
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.39 seconds. Users per second: 781
# Recommender MAP is= 0.07475753118278367
# Iteration =164
# a is= 0.8709286677591856 ,b is= 0.10391480975564688, c is= 0.41016661095806095
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.15 seconds. Users per second: 796
# Recommender MAP is= 0.07198611497463651
# Iteration =165
# a is= 0.5393252073097216 ,b is= 0.4583571762660634, c is= 0.33450466579795074
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.40 seconds. Users per second: 781
# Recommender MAP is= 0.07633678921613027
# Iteration =166
# a is= 0.36049135820738065 ,b is= 0.296015980650168, c is= 0.20021369290756463
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.05 seconds. Users per second: 803
# Recommender MAP is= 0.07713481542790122
# Iteration =167
# a is= 0.4011574488715105 ,b is= 0.6379823791228796, c is= 0.40419833623630186
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 10.83 seconds. Users per second: 893
# Recommender MAP is= 0.07555869565455121
# Iteration =168
# a is= 0.7590813531320281 ,b is= 0.6295743248281399, c is= 0.34469308065294785
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 10.94 seconds. Users per second: 884
# Recommender MAP is= 0.07911737550347563
# Iteration =169
# a is= 0.6119644566529984 ,b is= 0.1517587986863101, c is= 0.40225045642768076
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.01 seconds. Users per second: 879
# Recommender MAP is= 0.07100031543878564
# Iteration =170
# a is= 0.27376395739073117 ,b is= 0.5808769592099392, c is= 0.4205981843500569
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.16 seconds. Users per second: 867
# Recommender MAP is= 0.0738226256035692
# Iteration =171
# a is= 0.45331413821976396 ,b is= 0.15524530310660342, c is= 0.4402774035601177
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.42 seconds. Users per second: 779
# Recommender MAP is= 0.06867596512101712
# Iteration =172
# a is= 0.1640244335446256 ,b is= 0.33496996475781, c is= 0.2594976781168804
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.17 seconds. Users per second: 734
# Recommender MAP is= 0.07323136143878486
# Iteration =173
# a is= 0.6514557312649831 ,b is= 0.5138060816645601, c is= 0.17791367317469386
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.82 seconds. Users per second: 819
# Recommender MAP is= 0.08333796582073506
# Iteration =174
# a is= 0.2401087141044821 ,b is= 0.12550552702812443, c is= 0.40646498749931415
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.53 seconds. Users per second: 839
# Recommender MAP is= 0.06646712343952632
# Iteration =175
# a is= 0.5189049446478985 ,b is= 0.5907730563249772, c is= 0.4178211438069911
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.22 seconds. Users per second: 863
# Recommender MAP is= 0.075548260750873
# Iteration =176
# a is= 0.10468968518258706 ,b is= 0.2707957189746119, c is= 0.1715133014768782
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.92 seconds. Users per second: 812
# Recommender MAP is= 0.07438266577798412
# Iteration =177
# a is= 0.14647481614649793 ,b is= 0.13467681177521107, c is= 0.1551089214080931
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.11 seconds. Users per second: 738
# Recommender MAP is= 0.07206308818349984
# Iteration =178
# a is= 0.2959942140594257 ,b is= 0.22907996173093453, c is= 0.19404200128977084
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.25 seconds. Users per second: 679
# Recommender MAP is= 0.07543790513637054
# Iteration =179
# a is= 0.13051422791372477 ,b is= 0.5204737607705971, c is= 0.2356233958584173
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.07 seconds. Users per second: 688
# Recommender MAP is= 0.0764267100686061
# Iteration =180
# a is= 0.7345723071184008 ,b is= 0.11316746905597533, c is= 0.405083723006175
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.44 seconds. Users per second: 846
# Recommender MAP is= 0.07116565847531581
# Iteration =181
# a is= 0.2002032848811476 ,b is= 0.5780370875131968, c is= 0.2950104272837347
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.19 seconds. Users per second: 865
# Recommender MAP is= 0.07583874716748559
# Iteration =182
# a is= 0.11405078996777372 ,b is= 0.5431946381867403, c is= 0.34213781377259034
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.88 seconds. Users per second: 751
# Recommender MAP is= 0.07332781147019295
# Iteration =183
# a is= 0.43069126354936904 ,b is= 0.13777678651723874, c is= 0.30703645750146
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.26 seconds. Users per second: 789
# Recommender MAP is= 0.07097612544072188
# Iteration =184
# a is= 0.47132301173151336 ,b is= 0.6547080245601414, c is= 0.17296938581150417
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.86 seconds. Users per second: 698
# Recommender MAP is= 0.08319224420415196
# Iteration =185
# a is= 0.8081331606082867 ,b is= 0.6779116475144589, c is= 0.42067790227001745
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.35 seconds. Users per second: 784
# Recommender MAP is= 0.07792531899440051
# Iteration =186
# a is= 0.5255817820905012 ,b is= 0.5951744829513902, c is= 0.23364384262496352
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.46 seconds. Users per second: 777
# Recommender MAP is= 0.0811314745915821
# Iteration =187
# a is= 0.6237284087402475 ,b is= 0.21477954152570183, c is= 0.20603111986455655
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.46 seconds. Users per second: 844
# Recommender MAP is= 0.07856329967489858
# Iteration =188
# a is= 0.3817137921281494 ,b is= 0.14244682372247633, c is= 0.22613586916641948
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.50 seconds. Users per second: 717
# Recommender MAP is= 0.07308809823843035
# Iteration =189
# a is= 0.5886489210126581 ,b is= 0.3207953513691563, c is= 0.23007187177419777
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.91 seconds. Users per second: 696
# Recommender MAP is= 0.07867692527380708
# Iteration =190
# a is= 0.5058505628794863 ,b is= 0.6365682246872711, c is= 0.2325751139620664
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.30 seconds. Users per second: 787
# Recommender MAP is= 0.08117797563519621
# Iteration =191
# a is= 0.4764773425504525 ,b is= 0.35323849056997514, c is= 0.3842795156181976
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.34 seconds. Users per second: 725
# Recommender MAP is= 0.07353033058836204
# Iteration =192
# a is= 0.30978465595027704 ,b is= 0.44047760255801693, c is= 0.16866164534233924
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.37 seconds. Users per second: 673
# Recommender MAP is= 0.08030713165259368
# Iteration =193
# a is= 0.6625497125529053 ,b is= 0.42719017220794675, c is= 0.2667988594874714
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.44 seconds. Users per second: 555
# Recommender MAP is= 0.07890285696540181
# Iteration =194
# a is= 0.5855729795297493 ,b is= 0.15651498749887033, c is= 0.4895174458893943
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.19 seconds. Users per second: 637
# Recommender MAP is= 0.06911082889473838
# Iteration =195
# a is= 0.35503340119006566 ,b is= 0.18338622879448574, c is= 0.1698269773785707
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.64 seconds. Users per second: 581
# Recommender MAP is= 0.07658099365785531
# Iteration =196
# a is= 0.349262080300658 ,b is= 0.2714296216147187, c is= 0.3300615291167699
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.27 seconds. Users per second: 678
# Recommender MAP is= 0.07217147997486954
# Iteration =197
# a is= 0.4405452533673707 ,b is= 0.6539680290162877, c is= 0.276202123380177
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.00 seconds. Users per second: 569
# Recommender MAP is= 0.07950411822189861
# Iteration =198
# a is= 0.4465206254113875 ,b is= 0.6087442812353079, c is= 0.3782472558585577
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.48 seconds. Users per second: 668
# Recommender MAP is= 0.07604457340807634
# Iteration =199
# a is= 0.12276458872816304 ,b is= 0.32768391188587576, c is= 0.4607519958045241
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.89 seconds. Users per second: 650
# Recommender MAP is= 0.0678295109038517
# Iteration =200
# a is= 0.8311078086737954 ,b is= 0.5974429573480008, c is= 0.4476935886585498
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.52 seconds. Users per second: 716
# Recommender MAP is= 0.07695595622039171
# Iteration =201
# a is= 0.8127223445269116 ,b is= 0.26430085053574753, c is= 0.14264207084991784
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.65 seconds. Users per second: 660
# Recommender MAP is= 0.08371847701768065
# Iteration =202
# a is= 0.8835655172032392 ,b is= 0.6097537357562197, c is= 0.1146575980687286
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.79 seconds. Users per second: 654
# Recommender MAP is= 0.08616339583925074
# Iteration =203
# a is= 0.8135920964577229 ,b is= 0.18233664837692787, c is= 0.132401993238542
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.13 seconds. Users per second: 798
# Recommender MAP is= 0.083175131309088
# Iteration =204
# a is= 0.5459542562600965 ,b is= 0.20237173672555647, c is= 0.2870234445850355
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.30 seconds. Users per second: 728
# Recommender MAP is= 0.07428664403806
# Iteration =205
# a is= 0.5677997559316798 ,b is= 0.632816842418912, c is= 0.29993400841427487
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.23 seconds. Users per second: 791
# Recommender MAP is= 0.07918116422843374
# Iteration =206
# a is= 0.1615282003227021 ,b is= 0.4180322422950108, c is= 0.23638112360009653
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.17 seconds. Users per second: 735
# Recommender MAP is= 0.07528663516204169
# Iteration =207
# a is= 0.40275719430837664 ,b is= 0.4287449324367867, c is= 0.24833078927091812
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.66 seconds. Users per second: 764
# Recommender MAP is= 0.07749196455066013
# Iteration =208
# a is= 0.47456970716941294 ,b is= 0.2553128104220639, c is= 0.30788673695973656
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.39 seconds. Users per second: 629
# Recommender MAP is= 0.07378388036752069
# Iteration =209
# a is= 0.5073811901679662 ,b is= 0.4087051818794175, c is= 0.32413226686910473
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.67 seconds. Users per second: 618
# Recommender MAP is= 0.07607085607312596
# Iteration =210
# a is= 0.7087587646752241 ,b is= 0.693940294566496, c is= 0.3854674934065665
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.53 seconds. Users per second: 585
# Recommender MAP is= 0.07824620199828432
# Iteration =211
# a is= 0.7121144623747683 ,b is= 0.41189514122333204, c is= 0.21109460921286788
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.29 seconds. Users per second: 677
# Recommender MAP is= 0.08134645100786778
# Iteration =212
# a is= 0.44675259808642853 ,b is= 0.2712063696018203, c is= 0.24400638651497794
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.70 seconds. Users per second: 616
# Recommender MAP is= 0.07594122097857713
# Iteration =213
# a is= 0.7648353351236161 ,b is= 0.6401119869442884, c is= 0.23457156800575782
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.07 seconds. Users per second: 602
# Recommender MAP is= 0.08257230641517864
# Iteration =214
# a is= 0.8496772963737766 ,b is= 0.2658173103760328, c is= 0.4851377673630285
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.13 seconds. Users per second: 685
# Recommender MAP is= 0.07276050052827758
# Iteration =215
# a is= 0.44087723699227477 ,b is= 0.10267213833710137, c is= 0.292290636675606
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.85 seconds. Users per second: 651
# Recommender MAP is= 0.07075563080674536
# Iteration =216
# a is= 0.15487844893674207 ,b is= 0.5830416102330859, c is= 0.2714834772481256
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.56 seconds. Users per second: 622
# Recommender MAP is= 0.0761975057561644
# Iteration =217
# a is= 0.3668642079863108 ,b is= 0.3470997137185453, c is= 0.24690612383479513
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.29 seconds. Users per second: 633
# ...
# Recommender MAP is= 0.08197656414126606
# Iteration =282
# a is= 0.11911384982934017 ,b is= 0.5532500000101788, c is= 0.16848780537707614
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.82 seconds. Users per second: 819
# Recommender MAP is= 0.07931084790185128
# Iteration =283
# a is= 0.3448151511330523 ,b is= 0.3657833216329509, c is= 0.24665254114844146
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.70 seconds. Users per second: 827
# Recommender MAP is= 0.07618060478539691
# Iteration =284
# a is= 0.679451816134024 ,b is= 0.6762129742830796, c is= 0.2899946993246535
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.34 seconds. Users per second: 784
# Recommender MAP is= 0.08077014218541662
# Iteration =285
# a is= 0.3214888078022079 ,b is= 0.572106511723126, c is= 0.28184145422651785
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.36 seconds. Users per second: 630
# Recommender MAP is= 0.07743396177235903
# Iteration =286
# a is= 0.7493814047881654 ,b is= 0.5172291920878764, c is= 0.4458495625097688
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.32 seconds. Users per second: 632
# Recommender MAP is= 0.07565594501584269
# Iteration =287
# a is= 0.6807098534167808 ,b is= 0.5581007448384362, c is= 0.3176571281885601
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.68 seconds. Users per second: 580
# Recommender MAP is= 0.07884502728085084
# Iteration =288
# a is= 0.8682556265700812 ,b is= 0.5589535947037878, c is= 0.16479550827315687
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.41 seconds. Users per second: 780
# Recommender MAP is= 0.08467464451790552
# Iteration =289
# a is= 0.15287654339182116 ,b is= 0.3195877306265267, c is= 0.24281537356886412
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.30 seconds. Users per second: 787
# Recommender MAP is= 0.07341387224741219
# Iteration =290
# a is= 0.5737152120828242 ,b is= 0.15988949057161506, c is= 0.3948086676651864
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.10 seconds. Users per second: 800
# Recommender MAP is= 0.07082556820057807
# Iteration =291
# a is= 0.10070513952073626 ,b is= 0.6287432675907575, c is= 0.1790335349446011
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.17 seconds. Users per second: 598
# Recommender MAP is= 0.07936696689416352
# Iteration =292
# a is= 0.4684176833744126 ,b is= 0.1527813036678717, c is= 0.49915849547587066
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.24 seconds. Users per second: 679
# Recommender MAP is= 0.06813055686921943
# Iteration =293
# a is= 0.10818520515269886 ,b is= 0.2601732481141481, c is= 0.2919034394808028
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.00 seconds. Users per second: 744
# Recommender MAP is= 0.06961303476269327
# Iteration =294
# a is= 0.6124941086929989 ,b is= 0.5099384142958431, c is= 0.20499511284507035
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.81 seconds. Users per second: 755
# Recommender MAP is= 0.08202048964231479
# Iteration =295
# a is= 0.6496643976341259 ,b is= 0.5886775502432163, c is= 0.17172975237430665
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.22 seconds. Users per second: 862
# Recommender MAP is= 0.08395284943819979
# Iteration =296
# a is= 0.4078788798438503 ,b is= 0.6768161649343943, c is= 0.253346613454057
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.98 seconds. Users per second: 746
# Recommender MAP is= 0.08007520687469775
# Iteration =297
# a is= 0.3411320370350227 ,b is= 0.21783854556476837, c is= 0.1456021805345513
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.16 seconds. Users per second: 638
# Recommender MAP is= 0.07848419871159916
# Iteration =298
# a is= 0.7231775794416134 ,b is= 0.5726790019561241, c is= 0.26198943324479657
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.64 seconds. Users per second: 661
# Recommender MAP is= 0.08111883240082725
# Iteration =299
# a is= 0.46700973939467094 ,b is= 0.11992357702582349, c is= 0.16709601107805166
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.10 seconds. Users per second: 799
# Recommender MAP is= 0.07667589666793943
# Iteration =300
# a is= 0.8256111444642807 ,b is= 0.5062506712453103, c is= 0.21507046742860939
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.83 seconds. Users per second: 700
# Recommender MAP is= 0.08261307285763977
# Iteration =301
# a is= 0.46914448731175096 ,b is= 0.30276882170221425, c is= 0.3583608184595174
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.10 seconds. Users per second: 799
# Recommender MAP is= 0.07319215459770338
# Iteration =302
# a is= 0.7562250410215164 ,b is= 0.32538761747082756, c is= 0.129089597752159
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.10 seconds. Users per second: 739
# Recommender MAP is= 0.08437578740080072
# Iteration =303
# a is= 0.17146880179223684 ,b is= 0.5754070180015599, c is= 0.3490117628681343
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.57 seconds. Users per second: 770
# Recommender MAP is= 0.07413049451575962
# Iteration =304
# a is= 0.14620160020913336 ,b is= 0.5826381222952617, c is= 0.15875375428467098
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.79 seconds. Users per second: 821
# Recommender MAP is= 0.08031240394891732
# Iteration =305
# a is= 0.8437128689018503 ,b is= 0.6588485028378643, c is= 0.27859913003091874
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.23 seconds. Users per second: 791
# Recommender MAP is= 0.08189178828732205
# Iteration =306
# a is= 0.8022547806571398 ,b is= 0.6849237857482391, c is= 0.12644712603530783
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.81 seconds. Users per second: 819
# Recommender MAP is= 0.0857002323602952
# Iteration =307
# a is= 0.8722728293271842 ,b is= 0.4678664093831344, c is= 0.3338337753513524
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 11.54 seconds. Users per second: 838
# Recommender MAP is= 0.07874978099637109
# Iteration =308
# a is= 0.20513127555455535 ,b is= 0.5074811746650782, c is= 0.3748129161007461
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.75 seconds. Users per second: 703
# Recommender MAP is= 0.07330084730139347
# Iteration =309
# a is= 0.6923497531523862 ,b is= 0.34822366697724905, c is= 0.26539455930086375
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.77 seconds. Users per second: 758
# Recommender MAP is= 0.07856167637580037
# Iteration =310
# a is= 0.5893757155865439 ,b is= 0.4464156344691337, c is= 0.16834944047981049
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 19.21 seconds. Users per second: 504
# Recommender MAP is= 0.08274177185285506
# Iteration =311
# a is= 0.7930362698481516 ,b is= 0.5969609792437678, c is= 0.43675134762917045
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.93 seconds. Users per second: 695
# Recommender MAP is= 0.07696031116540733
# Iteration =312
# a is= 0.46876619603416014 ,b is= 0.6772716984960704, c is= 0.2802782227780215
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 20.19 seconds. Users per second: 479
# Recommender MAP is= 0.07970997938719676
# Iteration =313
# a is= 0.4711020374375481 ,b is= 0.4481736133616927, c is= 0.1673590186243834
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 21.15 seconds. Users per second: 457
# Recommender MAP is= 0.08209492885697141
# Iteration =314
# a is= 0.3968771828130686 ,b is= 0.27128418078744737, c is= 0.2838309115573579
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 19.24 seconds. Users per second: 503
# Recommender MAP is= 0.07407097772047135
# Iteration =315
# a is= 0.8902077834436765 ,b is= 0.3315006133878479, c is= 0.32335066999740114
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.08 seconds. Users per second: 602
# Recommender MAP is= 0.07795033953650805
# Iteration =316
# a is= 0.5620856500417554 ,b is= 0.25900752487966594, c is= 0.4451698291274995
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.49 seconds. Users per second: 717
# Recommender MAP is= 0.07132066355433828
# Iteration =317
# a is= 0.2581448500512953 ,b is= 0.32366228439400135, c is= 0.3609970240722703
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.12 seconds. Users per second: 685
# Recommender MAP is= 0.07114582474048835
# Iteration =318
# a is= 0.15395461671943134 ,b is= 0.4593071474333067, c is= 0.42317086401635173
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.86 seconds. Users per second: 698
# Recommender MAP is= 0.07079071252886807
# Iteration =319
# a is= 0.6352125426512857 ,b is= 0.6837728213159799, c is= 0.24429115951330088
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.31 seconds. Users per second: 676
# Recommender MAP is= 0.08195524685499274
# Iteration =320
# a is= 0.1759220133024389 ,b is= 0.6757321923995708, c is= 0.29326462848812157
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.74 seconds. Users per second: 704
# Recommender MAP is= 0.07681005695324676
# Iteration =321
# a is= 0.13937251189584812 ,b is= 0.3808318946374525, c is= 0.34278047041649484
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.68 seconds. Users per second: 763
# Recommender MAP is= 0.07112589409203883
# Iteration =322
# a is= 0.8648093692801468 ,b is= 0.6727699499749283, c is= 0.44586481966968483
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.11 seconds. Users per second: 799
# Recommender MAP is= 0.07760850029231288
# Iteration =323
# a is= 0.2543973039066204 ,b is= 0.108264020998995, c is= 0.3299560949751399
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.03 seconds. Users per second: 689
# Recommender MAP is= 0.06747467310994658
# Iteration =324
# a is= 0.5015240893745955 ,b is= 0.19212541893254015, c is= 0.3851358466080177
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.27 seconds. Users per second: 729
# Recommender MAP is= 0.07091676219371597
# Iteration =325
# a is= 0.8491860626908352 ,b is= 0.6480602905691556, c is= 0.17971440374107153
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.20 seconds. Users per second: 733
# Recommender MAP is= 0.08453773051869228
# Iteration =326
# a is= 0.2036000012309903 ,b is= 0.34978399665903137, c is= 0.2486361823926032
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.06 seconds. Users per second: 741
# Recommender MAP is= 0.07447186287855516
# Iteration =327
# a is= 0.22049552356556168 ,b is= 0.29013388545245394, c is= 0.12451128691835717
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 12.79 seconds. Users per second: 757
# Recommender MAP is= 0.07969628927620213
# Iteration =328
# a is= 0.7203517872950933 ,b is= 0.2020885129858338, c is= 0.49445562500566786
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.76 seconds. Users per second: 545
# Recommender MAP is= 0.0708947980680108
# Iteration =329
# a is= 0.6623307497308354 ,b is= 0.21528665752757686, c is= 0.2352783996820536
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.84 seconds. Users per second: 542
# Recommender MAP is= 0.07767141858485005
# Iteration =330
# a is= 0.6862010368254658 ,b is= 0.1348291201858084, c is= 0.4733485450437618
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.55 seconds. Users per second: 665
# Recommender MAP is= 0.06991678545624003
# Iteration =331
# a is= 0.48535475956405716 ,b is= 0.5957266390350755, c is= 0.34354262215760045
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.82 seconds. Users per second: 612
# Recommender MAP is= 0.07708323329504024
# Iteration =332
# a is= 0.32275327324057407 ,b is= 0.12815130639101632, c is= 0.15450533220835116
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.51 seconds. Users per second: 586
# Recommender MAP is= 0.07542737102438996
# Iteration =333
# a is= 0.10355885102570284 ,b is= 0.14407059578165762, c is= 0.2190475792392924
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.87 seconds. Users per second: 698
# Recommender MAP is= 0.06823040937433575
# Iteration =334
# a is= 0.2510029766222093 ,b is= 0.15876434610393467, c is= 0.4952693331697473
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.40 seconds. Users per second: 628
# Recommender MAP is= 0.06614082305368678
# Iteration =335
# a is= 0.13585321461448308 ,b is= 0.33273784704448317, c is= 0.186589014869305
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.24 seconds. Users per second: 635
# Recommender MAP is= 0.07553871535312771
# Iteration =336
# a is= 0.4516840398626246 ,b is= 0.2771617730034935, c is= 0.39500313177816426
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.02 seconds. Users per second: 568
# Recommender MAP is= 0.07161558602721652
# Iteration =337
# a is= 0.8008150498013211 ,b is= 0.19084325634311156, c is= 0.20060704124540685
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 20.20 seconds. Users per second: 479
# Recommender MAP is= 0.07985402377155913
# Iteration =338
# a is= 0.13521834678501526 ,b is= 0.387924903884706, c is= 0.1661434757864028
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 25.58 seconds. Users per second: 378
# Recommender MAP is= 0.07748955015648852
# Iteration =339
# a is= 0.8446051373150227 ,b is= 0.5195150893129805, c is= 0.1020614619309752
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 25.77 seconds. Users per second: 375
# Recommender MAP is= 0.08623386870729043
# Iteration =340
# a is= 0.5280836238650614 ,b is= 0.6107772944359621, c is= 0.42004581841869715
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 21.46 seconds. Users per second: 451
# Recommender MAP is= 0.07576597361400265
# Iteration =341
# a is= 0.7875949355426569 ,b is= 0.19682355282059394, c is= 0.2589096860668072
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 19.24 seconds. Users per second: 503
# Recommender MAP is= 0.0772722961317563
# Iteration =342
# a is= 0.7903278050818098 ,b is= 0.5887355510309857, c is= 0.17205403828940075
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.93 seconds. Users per second: 571
# Recommender MAP is= 0.08435457207319101
# Iteration =343
# a is= 0.7254220812815529 ,b is= 0.28151920967531474, c is= 0.36502978259670504
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 16.41 seconds. Users per second: 590
# Recommender MAP is= 0.07476659106850819
# Iteration =344
# a is= 0.25565477383274027 ,b is= 0.36423708809794864, c is= 0.47362022011428173
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.33 seconds. Users per second: 558
# Recommender MAP is= 0.06948065842037367
# Iteration =345
# a is= 0.30798872320297155 ,b is= 0.22877714807043784, c is= 0.45639014809452383
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 17.22 seconds. Users per second: 562
# Recommender MAP is= 0.06809627699950052
# Iteration =346
# a is= 0.5545770773131716 ,b is= 0.38761156580159584, c is= 0.22464583588119644
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.45 seconds. Users per second: 670
# Recommender MAP is= 0.07939390451953442
# Iteration =347
# a is= 0.6954870937478946 ,b is= 0.4674849117493962, c is= 0.4002539361237418
# SequentialEvaluator: Processed 3001 ( 31.01% ) in 1008.89 seconds. Users per second: 3
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 1021.45 seconds. Users per second: 9
# Recommender MAP is= 0.0758985217969493
# Iteration =348
# a is= 0.3843190331468498 ,b is= 0.3163855501736277, c is= 0.4242374398602471
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 15.64 seconds. Users per second: 619
# Recommender MAP is= 0.07105093920903242
# Iteration =349
# a is= 0.26176782546085375 ,b is= 0.6281737499063492, c is= 0.26482510347420446
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.11 seconds. Users per second: 686
# Recommender MAP is= 0.07818334468565331
# Iteration =350
# a is= 0.38924096748985515 ,b is= 0.2333691895791484, c is= 0.4537958026364205
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.10 seconds. Users per second: 686
# Recommender MAP is= 0.06908161685068906
# Iteration =351
# a is= 0.6171345550785163 ,b is= 0.12005262002642048, c is= 0.28101691841856813
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 14.11 seconds. Users per second: 686
# Recommender MAP is= 0.07342156010965926
# Iteration =352
# a is= 0.17749828850731522 ,b is= 0.33089954166356184, c is= 0.4887010758515794
# SequentialEvaluator: Processed 9676 ( 100.00% ) in 13.51 seconds. Users per second: 716
# Recommender MAP is= 0.06796828811830337
# Iteration =353
# a is= 0.766716668780745 ,b is= 0.19928933213196565, c is= 0.11363720681420958

# %%
import pandas as pd
from numpy import *
import numpy as np
from scipy import sparse



train_df= pd.read_csv('all/train.csv',low_memory = False)
target_playlist_df= pd.read_csv('all/target_playlists.csv',low_memory = False)

random_playlist_df=target_playlist_df.iloc[5000:10000]
sequential_playlist_df=target_playlist_df.iloc[:5000]


#-----CALCOLO DF per TEST
#prendo il 20% delle random playlist da target playlist
random_id = random_playlist_df.playlist_id.values
random_data=train_df.loc[train_df['playlist_id'].isin(random_id)]
#random_data.shape = (114513, 2)
n=round((114513/100)*20)
random_test_df = random_data.sample(n=n)

#prendo il 20% delle sequential playlist da target playlist
sequential_id = sequential_playlist_df.playlist_id.values
sequential_data=train_df.loc[train_df['playlist_id'].isin(sequential_id)]
n1=round((115553/100)*20)
for pid in sequential_id:
    playlistID=sequential_data.loc[sequential_data['playlist_id']==pid]
    start=sequential_data.index[sequential_data['playlist_id'] == pid][0]
    end=start+round((playlistID.shape[0]*50)/100)

    dropping=list(range(start, end))    
    sequential_data=sequential_data.drop(dropping)


sequential_test_df = sequential_data.sample(n=n1)

# %%
#SETTO URM TEST
URM_test_sequential=zeros((50446,20635))
URM_test_random=zeros((50446,20635))



#20% from random
for row in random_test_df.itertuples():
    riga = row.playlist_id
    #print(riga)
    colonna= row.track_id
    #print(colonna)
    URM_test_random[riga,colonna]=1
#20% from random
for row in sequential_test_df.itertuples():
    riga = row.playlist_id
    #print(riga)
    colonna= row.track_id
    #print(colonna)
    URM_test_sequential[riga,colonna]=1

URM_test_sequential=sparse.csr_matrix(URM_test_sequential) 
URM_test_random=sparse.csr_matrix(URM_test_random)

# %%
# Out:
# Similarity column 20635 ( 100 % ), 3164.50 column/sec, elapsed time 0.11 min
# SLIM_BPR_Cython: Estimated memory required for similarity matrix of 20635 items is 1703.21 MB
# Processed 1165777 ( 100.00% ) in 8.50 seconds. BPR loss is 9.42E-01. Sample per second: 137173
# SLIM_BPR_Recommender: Epoch 1 of 100. Elapsed time 0.33 min
# Processed 1165777 ( 100.00% ) in 7.04 seconds. BPR loss is 2.13E+00. Sample per second: 165575
# SLIM_BPR_Recommender: Epoch 2 of 100. Elapsed time 0.44 min
# Processed 1165777 ( 100.00% ) in 5.59 seconds. BPR loss is 2.96E+00. Sample per second: 208672
# SLIM_BPR_Recommender: Epoch 3 of 100. Elapsed time 0.53 min
# Processed 1165777 ( 100.00% ) in 6.00 seconds. BPR loss is 3.66E+00. Sample per second: 194314
# SLIM_BPR_Recommender: Epoch 4 of 100. Elapsed time 0.62 min
# Processed 1165777 ( 100.00% ) in 6.67 seconds. BPR loss is 4.24E+00. Sample per second: 174732
# SLIM_BPR_Recommender: Epoch 5 of 100. Elapsed time 0.74 min
# Processed 1165777 ( 100.00% ) in 6.37 seconds. BPR loss is 4.76E+00. Sample per second: 183056
# SLIM_BPR_Recommender: Epoch 6 of 100. Elapsed time 0.83 min
# Processed 1165777 ( 100.00% ) in 6.32 seconds. BPR loss is 5.24E+00. Sample per second: 184394
# SLIM_BPR_Recommender: Epoch 7 of 100. Elapsed time 0.93 min
# Processed 1165777 ( 100.00% ) in 7.32 seconds. BPR loss is 5.69E+00. Sample per second: 159208
# SLIM_BPR_Recommender: Epoch 8 of 100. Elapsed time 1.05 min
# Processed 1165777 ( 100.00% ) in 5.90 seconds. BPR loss is 6.09E+00. Sample per second: 197654
# SLIM_BPR_Recommender: Epoch 9 of 100. Elapsed time 1.14 min
# Processed 1165777 ( 100.00% ) in 6.44 seconds. BPR loss is 6.47E+00. Sample per second: 181161
# SLIM_BPR_Recommender: Epoch 10 of 100. Elapsed time 1.23 min
# Processed 1165777 ( 100.00% ) in 5.59 seconds. BPR loss is 6.83E+00. Sample per second: 208565
# SLIM_BPR_Recommender: Epoch 11 of 100. Elapsed time 1.32 min
# Processed 1165777 ( 100.00% ) in 6.08 seconds. BPR loss is 7.14E+00. Sample per second: 191665
# SLIM_BPR_Recommender: Epoch 12 of 100. Elapsed time 1.41 min
# Processed 1165777 ( 100.00% ) in 6.84 seconds. BPR loss is 7.45E+00. Sample per second: 170334
# SLIM_BPR_Recommender: Epoch 13 of 100. Elapsed time 1.52 min
# Processed 1165777 ( 100.00% ) in 6.97 seconds. BPR loss is 7.79E+00. Sample per second: 167202
# SLIM_BPR_Recommender: Epoch 14 of 100. Elapsed time 1.62 min
# Processed 1165777 ( 100.00% ) in 7.36 seconds. BPR loss is 8.09E+00. Sample per second: 158300
# SLIM_BPR_Recommender: Epoch 15 of 100. Elapsed time 1.73 min
# Processed 1165777 ( 100.00% ) in 6.05 seconds. BPR loss is 8.34E+00. Sample per second: 192739
# SLIM_BPR_Recommender: Epoch 16 of 100. Elapsed time 1.83 min
# Processed 1165777 ( 100.00% ) in 6.50 seconds. BPR loss is 8.65E+00. Sample per second: 179372
# SLIM_BPR_Recommender: Epoch 17 of 100. Elapsed time 1.93 min
# Processed 1165777 ( 100.00% ) in 7.12 seconds. BPR loss is 8.89E+00. Sample per second: 163768
# SLIM_BPR_Recommender: Epoch 18 of 100. Elapsed time 2.04 min
# Processed 1165777 ( 100.00% ) in 5.40 seconds. BPR loss is 9.16E+00. Sample per second: 215925
# SLIM_BPR_Recommender: Epoch 19 of 100. Elapsed time 2.13 min
# Processed 1165777 ( 100.00% ) in 6.35 seconds. BPR loss is 9.39E+00. Sample per second: 183495
# SLIM_BPR_Recommender: Epoch 20 of 100. Elapsed time 2.23 min
# Processed 1165777 ( 100.00% ) in 6.35 seconds. BPR loss is 9.60E+00. Sample per second: 183510
# SLIM_BPR_Recommender: Epoch 21 of 100. Elapsed time 2.33 min
# Processed 1165777 ( 100.00% ) in 7.06 seconds. BPR loss is 9.84E+00. Sample per second: 165180
# SLIM_BPR_Recommender: Epoch 22 of 100. Elapsed time 2.44 min
# Processed 1165777 ( 100.00% ) in 6.65 seconds. BPR loss is 1.01E+01. Sample per second: 175393
# SLIM_BPR_Recommender: Epoch 23 of 100. Elapsed time 2.55 min
# Processed 1165777 ( 100.00% ) in 7.16 seconds. BPR loss is 1.03E+01. Sample per second: 162863
# SLIM_BPR_Recommender: Epoch 24 of 100. Elapsed time 2.66 min
# Processed 1165777 ( 100.00% ) in 5.30 seconds. BPR loss is 1.05E+01. Sample per second: 219779
# SLIM_BPR_Recommender: Epoch 25 of 100. Elapsed time 2.75 min
# Processed 1165777 ( 100.00% ) in 6.53 seconds. BPR loss is 1.07E+01. Sample per second: 178394
# SLIM_BPR_Recommender: Epoch 26 of 100. Elapsed time 2.85 min
# Processed 1165777 ( 100.00% ) in 6.03 seconds. BPR loss is 1.09E+01. Sample per second: 193303
# SLIM_BPR_Recommender: Epoch 27 of 100. Elapsed time 2.94 min
# Processed 1165777 ( 100.00% ) in 6.45 seconds. BPR loss is 1.11E+01. Sample per second: 180685
# SLIM_BPR_Recommender: Epoch 28 of 100. Elapsed time 3.05 min
# Processed 1165777 ( 100.00% ) in 5.77 seconds. BPR loss is 1.13E+01. Sample per second: 201945
# SLIM_BPR_Recommender: Epoch 29 of 100. Elapsed time 3.14 min
# Processed 1165777 ( 100.00% ) in 6.63 seconds. BPR loss is 1.14E+01. Sample per second: 175833
# SLIM_BPR_Recommender: Epoch 30 of 100. Elapsed time 3.24 min
# Processed 1165777 ( 100.00% ) in 6.67 seconds. BPR loss is 1.16E+01. Sample per second: 174681
# SLIM_BPR_Recommender: Epoch 31 of 100. Elapsed time 3.34 min
# Processed 1165777 ( 100.00% ) in 6.16 seconds. BPR loss is 1.18E+01. Sample per second: 189352
# SLIM_BPR_Recommender: Epoch 32 of 100. Elapsed time 3.43 min
# Processed 1165777 ( 100.00% ) in 5.03 seconds. BPR loss is 1.20E+01. Sample per second: 231860
# SLIM_BPR_Recommender: Epoch 33 of 100. Elapsed time 3.51 min
# Processed 1165777 ( 100.00% ) in 6.02 seconds. BPR loss is 1.22E+01. Sample per second: 193687
# SLIM_BPR_Recommender: Epoch 34 of 100. Elapsed time 3.61 min
# Processed 1165777 ( 100.00% ) in 6.19 seconds. BPR loss is 1.23E+01. Sample per second: 188285
# SLIM_BPR_Recommender: Epoch 35 of 100. Elapsed time 3.71 min
# Processed 1165777 ( 100.00% ) in 7.13 seconds. BPR loss is 1.25E+01. Sample per second: 163487
# SLIM_BPR_Recommender: Epoch 36 of 100. Elapsed time 3.83 min
# Processed 1165777 ( 100.00% ) in 6.28 seconds. BPR loss is 1.26E+01. Sample per second: 185718
# SLIM_BPR_Recommender: Epoch 37 of 100. Elapsed time 3.93 min
# Processed 1165777 ( 100.00% ) in 6.68 seconds. BPR loss is 1.28E+01. Sample per second: 174626
# SLIM_BPR_Recommender: Epoch 38 of 100. Elapsed time 4.04 min
# Processed 1165777 ( 100.00% ) in 6.54 seconds. BPR loss is 1.29E+01. Sample per second: 178351
# SLIM_BPR_Recommender: Epoch 39 of 100. Elapsed time 4.13 min
# Processed 1165777 ( 100.00% ) in 6.41 seconds. BPR loss is 1.31E+01. Sample per second: 181961
# SLIM_BPR_Recommender: Epoch 40 of 100. Elapsed time 4.23 min
# Processed 1165777 ( 100.00% ) in 5.57 seconds. BPR loss is 1.32E+01. Sample per second: 209307
# SLIM_BPR_Recommender: Epoch 41 of 100. Elapsed time 4.32 min
# Processed 1165777 ( 100.00% ) in 6.96 seconds. BPR loss is 1.34E+01. Sample per second: 167399
# SLIM_BPR_Recommender: Epoch 42 of 100. Elapsed time 4.42 min
# Processed 1165777 ( 100.00% ) in 6.33 seconds. BPR loss is 1.35E+01. Sample per second: 184268
# SLIM_BPR_Recommender: Epoch 43 of 100. Elapsed time 4.51 min
# Processed 1165777 ( 100.00% ) in 6.33 seconds. BPR loss is 1.37E+01. Sample per second: 184049
# SLIM_BPR_Recommender: Epoch 44 of 100. Elapsed time 4.61 min
# Processed 1165777 ( 100.00% ) in 5.83 seconds. BPR loss is 1.39E+01. Sample per second: 199811
# SLIM_BPR_Recommender: Epoch 45 of 100. Elapsed time 4.71 min
# Processed 1165777 ( 100.00% ) in 6.82 seconds. BPR loss is 1.40E+01. Sample per second: 170898
# SLIM_BPR_Recommender: Epoch 46 of 100. Elapsed time 4.80 min
# Processed 1165777 ( 100.00% ) in 6.37 seconds. BPR loss is 1.41E+01. Sample per second: 182871
# SLIM_BPR_Recommender: Epoch 47 of 100. Elapsed time 4.90 min
# Processed 1165777 ( 100.00% ) in 6.10 seconds. BPR loss is 1.42E+01. Sample per second: 190993
# SLIM_BPR_Recommender: Epoch 48 of 100. Elapsed time 4.99 min
# Processed 1165777 ( 100.00% ) in 5.85 seconds. BPR loss is 1.44E+01. Sample per second: 199147
# SLIM_BPR_Recommender: Epoch 49 of 100. Elapsed time 5.09 min
# Processed 1165777 ( 100.00% ) in 6.68 seconds. BPR loss is 1.45E+01. Sample per second: 174397
# SLIM_BPR_Recommender: Epoch 50 of 100. Elapsed time 5.19 min
# Processed 1165777 ( 100.00% ) in 7.54 seconds. BPR loss is 1.46E+01. Sample per second: 154587
# SLIM_BPR_Recommender: Epoch 51 of 100. Elapsed time 5.30 min
# Processed 1165777 ( 100.00% ) in 6.47 seconds. BPR loss is 1.48E+01. Sample per second: 180257
# SLIM_BPR_Recommender: Epoch 52 of 100. Elapsed time 5.40 min
# Processed 1165777 ( 100.00% ) in 7.11 seconds. BPR loss is 1.49E+01. Sample per second: 164078
# SLIM_BPR_Recommender: Epoch 53 of 100. Elapsed time 5.51 min
# Processed 1165777 ( 100.00% ) in 5.82 seconds. BPR loss is 1.49E+01. Sample per second: 200274
# SLIM_BPR_Recommender: Epoch 54 of 100. Elapsed time 5.60 min
# Processed 1165777 ( 100.00% ) in 7.02 seconds. BPR loss is 1.51E+01. Sample per second: 166080
# SLIM_BPR_Recommender: Epoch 55 of 100. Elapsed time 5.71 min
# Processed 1165777 ( 100.00% ) in 6.70 seconds. BPR loss is 1.52E+01. Sample per second: 173889
# SLIM_BPR_Recommender: Epoch 56 of 100. Elapsed time 5.82 min
# Processed 1165777 ( 100.00% ) in 7.08 seconds. BPR loss is 1.54E+01. Sample per second: 164685
# SLIM_BPR_Recommender: Epoch 57 of 100. Elapsed time 5.93 min
# Processed 1165777 ( 100.00% ) in 7.54 seconds. BPR loss is 1.55E+01. Sample per second: 154613
# SLIM_BPR_Recommender: Epoch 58 of 100. Elapsed time 6.05 min
# Processed 1165777 ( 100.00% ) in 6.38 seconds. BPR loss is 1.56E+01. Sample per second: 182624
# SLIM_BPR_Recommender: Epoch 59 of 100. Elapsed time 6.15 min
# Processed 1165777 ( 100.00% ) in 6.56 seconds. BPR loss is 1.56E+01. Sample per second: 177649
# SLIM_BPR_Recommender: Epoch 60 of 100. Elapsed time 6.25 min
# Processed 1165777 ( 100.00% ) in 6.05 seconds. BPR loss is 1.58E+01. Sample per second: 192705
# SLIM_BPR_Recommender: Epoch 61 of 100. Elapsed time 6.34 min
# Processed 1165777 ( 100.00% ) in 6.24 seconds. BPR loss is 1.59E+01. Sample per second: 186675
# SLIM_BPR_Recommender: Epoch 62 of 100. Elapsed time 6.45 min
# Processed 1165777 ( 100.00% ) in 5.70 seconds. BPR loss is 1.60E+01. Sample per second: 204592
# SLIM_BPR_Recommender: Epoch 63 of 100. Elapsed time 6.54 min
# Processed 1165777 ( 100.00% ) in 6.80 seconds. BPR loss is 1.61E+01. Sample per second: 171562
# SLIM_BPR_Recommender: Epoch 64 of 100. Elapsed time 6.64 min
# Processed 1165777 ( 100.00% ) in 6.56 seconds. BPR loss is 1.62E+01. Sample per second: 177597
# SLIM_BPR_Recommender: Epoch 65 of 100. Elapsed time 6.73 min
# Processed 1165777 ( 100.00% ) in 6.26 seconds. BPR loss is 1.63E+01. Sample per second: 186157
# SLIM_BPR_Recommender: Epoch 66 of 100. Elapsed time 6.83 min
# Processed 1165777 ( 100.00% ) in 6.52 seconds. BPR loss is 1.64E+01. Sample per second: 178756
# SLIM_BPR_Recommender: Epoch 67 of 100. Elapsed time 6.93 min
# Processed 1165777 ( 100.00% ) in 6.48 seconds. BPR loss is 1.66E+01. Sample per second: 179802
# SLIM_BPR_Recommender: Epoch 68 of 100. Elapsed time 7.03 min
# Processed 1165777 ( 100.00% ) in 6.69 seconds. BPR loss is 1.66E+01. Sample per second: 174357
# SLIM_BPR_Recommender: Epoch 69 of 100. Elapsed time 7.14 min
# Processed 1165777 ( 100.00% ) in 6.48 seconds. BPR loss is 1.67E+01. Sample per second: 179784
# SLIM_BPR_Recommender: Epoch 70 of 100. Elapsed time 7.23 min
# Processed 1165777 ( 100.00% ) in 6.97 seconds. BPR loss is 1.68E+01. Sample per second: 167299
# SLIM_BPR_Recommender: Epoch 71 of 100. Elapsed time 7.34 min
# Processed 1165777 ( 100.00% ) in 7.51 seconds. BPR loss is 1.69E+01. Sample per second: 155232
# SLIM_BPR_Recommender: Epoch 72 of 100. Elapsed time 7.45 min
# Processed 1165777 ( 100.00% ) in 7.38 seconds. BPR loss is 1.70E+01. Sample per second: 158030
# SLIM_BPR_Recommender: Epoch 73 of 100. Elapsed time 7.56 min
# Processed 1165777 ( 100.00% ) in 6.69 seconds. BPR loss is 1.71E+01. Sample per second: 174350
# SLIM_BPR_Recommender: Epoch 74 of 100. Elapsed time 7.67 min
# Processed 1165777 ( 100.00% ) in 7.68 seconds. BPR loss is 1.72E+01. Sample per second: 151806
# SLIM_BPR_Recommender: Epoch 75 of 100. Elapsed time 7.79 min
# Processed 1165777 ( 100.00% ) in 6.83 seconds. BPR loss is 1.73E+01. Sample per second: 170718
# SLIM_BPR_Recommender: Epoch 76 of 100. Elapsed time 7.89 min
# Processed 1165777 ( 100.00% ) in 7.60 seconds. BPR loss is 1.74E+01. Sample per second: 153444
# SLIM_BPR_Recommender: Epoch 77 of 100. Elapsed time 8.00 min
# Processed 1165777 ( 100.00% ) in 5.95 seconds. BPR loss is 1.75E+01. Sample per second: 195949
# SLIM_BPR_Recommender: Epoch 78 of 100. Elapsed time 8.09 min
# Processed 1165777 ( 100.00% ) in 7.66 seconds. BPR loss is 1.76E+01. Sample per second: 152233
# SLIM_BPR_Recommender: Epoch 79 of 100. Elapsed time 8.20 min
# Processed 1165777 ( 100.00% ) in 7.75 seconds. BPR loss is 1.77E+01. Sample per second: 150394
# SLIM_BPR_Recommender: Epoch 80 of 100. Elapsed time 8.32 min
# Processed 1165777 ( 100.00% ) in 7.45 seconds. BPR loss is 1.77E+01. Sample per second: 156566
# SLIM_BPR_Recommender: Epoch 81 of 100. Elapsed time 8.43 min
# Processed 1165777 ( 100.00% ) in 7.65 seconds. BPR loss is 1.78E+01. Sample per second: 152342
# SLIM_BPR_Recommender: Epoch 82 of 100. Elapsed time 8.55 min
# Processed 1165777 ( 100.00% ) in 7.99 seconds. BPR loss is 1.79E+01. Sample per second: 145976
# SLIM_BPR_Recommender: Epoch 83 of 100. Elapsed time 8.67 min
# Processed 1165777 ( 100.00% ) in 10.02 seconds. BPR loss is 1.80E+01. Sample per second: 116318
# SLIM_BPR_Recommender: Epoch 84 of 100. Elapsed time 8.82 min
# Processed 1165777 ( 100.00% ) in 7.05 seconds. BPR loss is 1.80E+01. Sample per second: 165379
# SLIM_BPR_Recommender: Epoch 85 of 100. Elapsed time 8.94 min
# Processed 1165777 ( 100.00% ) in 8.58 seconds. BPR loss is 1.81E+01. Sample per second: 135913
# SLIM_BPR_Recommender: Epoch 86 of 100. Elapsed time 9.08 min
# Processed 1165777 ( 100.00% ) in 5.98 seconds. BPR loss is 1.82E+01. Sample per second: 194908
# SLIM_BPR_Recommender: Epoch 87 of 100. Elapsed time 9.17 min
# Processed 1165777 ( 100.00% ) in 7.70 seconds. BPR loss is 1.84E+01. Sample per second: 151330
# SLIM_BPR_Recommender: Epoch 88 of 100. Elapsed time 9.29 min
# Processed 1165777 ( 100.00% ) in 7.56 seconds. BPR loss is 1.84E+01. Sample per second: 154224
# SLIM_BPR_Recommender: Epoch 89 of 100. Elapsed time 9.40 min
# Processed 1165777 ( 100.00% ) in 5.81 seconds. BPR loss is 1.85E+01. Sample per second: 200634
# SLIM_BPR_Recommender: Epoch 90 of 100. Elapsed time 9.49 min
# Processed 1165777 ( 100.00% ) in 7.93 seconds. BPR loss is 1.86E+01. Sample per second: 147063
# SLIM_BPR_Recommender: Epoch 91 of 100. Elapsed time 9.61 min
# Processed 1165777 ( 100.00% ) in 7.01 seconds. BPR loss is 1.86E+01. Sample per second: 166207
# SLIM_BPR_Recommender: Epoch 92 of 100. Elapsed time 9.71 min
# Processed 1165777 ( 100.00% ) in 6.58 seconds. BPR loss is 1.87E+01. Sample per second: 177186
# SLIM_BPR_Recommender: Epoch 93 of 100. Elapsed time 9.82 min
# Processed 1165777 ( 100.00% ) in 6.36 seconds. BPR loss is 1.88E+01. Sample per second: 183432
# SLIM_BPR_Recommender: Epoch 94 of 100. Elapsed time 9.91 min
# Processed 1165777 ( 100.00% ) in 6.52 seconds. BPR loss is 1.89E+01. Sample per second: 178837
# SLIM_BPR_Recommender: Epoch 95 of 100. Elapsed time 10.02 min
# Processed 1165777 ( 100.00% ) in 6.41 seconds. BPR loss is 1.89E+01. Sample per second: 181979
# SLIM_BPR_Recommender: Epoch 96 of 100. Elapsed time 10.11 min
# Processed 1165777 ( 100.00% ) in 6.52 seconds. BPR loss is 1.91E+01. Sample per second: 178696
# SLIM_BPR_Recommender: Epoch 97 of 100. Elapsed time 10.22 min
# Processed 1165777 ( 100.00% ) in 6.51 seconds. BPR loss is 1.91E+01. Sample per second: 179117
# SLIM_BPR_Recommender: Epoch 98 of 100. Elapsed time 10.32 min
# Processed 1165777 ( 100.00% ) in 6.67 seconds. BPR loss is 1.92E+01. Sample per second: 174762
# SLIM_BPR_Recommender: Epoch 99 of 100. Elapsed time 10.42 min
# Processed 1165777 ( 100.00% ) in 6.92 seconds. BPR loss is 1.93E+01. Sample per second: 168540
# SLIM_BPR_Recommender: Epoch 100 of 100. Elapsed time 10.52 min
# Similarity column 20635 ( 100 % ), 4734.51 column/sec, elapsed time 0.07 min
# Processed 2952 ( 14.31% ) in 5.00 minutes. Items per second: 10
# Processed 6105 ( 29.59% ) in 10.00 minutes. Items per second: 10
# Processed 8861 ( 42.94% ) in 15.00 minutes. Items per second: 10
# Processed 11553 ( 55.99% ) in 20.00 minutes. Items per second: 10
# Processed 13898 ( 67.35% ) in 25.00 minutes. Items per second: 9
# Processed 16222 ( 78.61% ) in 30.01 minutes. Items per second: 9
# Processed 16665 ( 80.76% ) in 91.83 minutes. Items per second: 3
# Processed 18406 ( 89.20% ) in 96.83 minutes. Items per second: 3
# Processed 20635 ( 100.00% ) in 101.29 minutes. Items per second: 3
# Similarity column 50446 ( 100 % ), 1021.03 column/sec, elapsed time 0.82 min

# %%
print("CF Recommender")
result = CFrecommender.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = CFrecommender.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("CBF Recommender")
result = CBFrecommender.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = CBFrecommender.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("SLIM Recommender")
result = SLIMrecommender.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = SLIMrecommender.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("SLIME Recommender")

result = SLIMErecommender.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = SLIMErecommender.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("UCF Recommender")
result = UCFRecommender.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = UCFRecommender.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# CF Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 5.03 seconds. Users per second: 964
# Recommender MAP is= 0.02942449345203795
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 4.59 seconds. Users per second: 1048
# Recommender MAP is= 0.014638956384624932
# CBF Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 2.83 seconds. Users per second: 1710
# Recommender MAP is= 0.016561521949034503
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 2.81 seconds. Users per second: 1713
# Recommender MAP is= 0.006558907123089322
# SLIM Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 4.74 seconds. Users per second: 1022
# Recommender MAP is= 0.030322088576369803
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 5.19 seconds. Users per second: 927
# Recommender MAP is= 0.01553595515940238
# SLIME Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 6.83 seconds. Users per second: 709
# Recommender MAP is= 0.03314535798581742
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 5.93 seconds. Users per second: 811
# Recommender MAP is= 0.016305353874208093
# UCF Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 4.62 seconds. Users per second: 1049
# Recommender MAP is= 0.027829361090634764
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 3.98 seconds. Users per second: 1208
# Recommender MAP is= 0.014935937295504716

# %%
superSlim=ItemKNNSimilarityHybridRecommender(URM_train,SLIMrecommender,SLIMErecommender)
superSlim.fit(topK=600, alpha = 0.5)

hybrid1=ItemKNNSimilarityHybridRecommender3(URM_train,superSlim, CFrecommender,CBFrecommender)
hybrid1.fit(topK=800, alpha=0.7, beta=0.4, gamma=0.2)

# %%
tmpRec=ItemKNNSimilarityHybridRecommender3(URM_train,superSlim, CFrecommender,CBFrecommender)
tmpRec.fit(topK=1000,alpha=0.6,beta=0.2,gamma=0.2)
hybrid2=ItemKNNScoresHybridRecommender(URM_train,tmpRec,UCFRecommender)
hybrid2.fit(alpha=0.7)

# %%
hybrid3 = ItemKNNSimilarityHybridRecommender4(URM_train, SLIMrecommender, SLIMErecommender, CFrecommender,CBFrecommender)
hybrid3.fit(topK=400, alpha=0.486, beta=0.4547, gamma=0.4198, delta=0.255)

# %%
print("Hybrid1 Recommender")
result = hybrid1.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = hybrid1.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("Hybrid2 Recommender")

result = hybrid2.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = hybrid2.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("Hybrid3 Recommender")
result = hybrid3.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = hybrid3.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# Hybrid1 Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 5.00 seconds. Users per second: 970
# Recommender MAP is= 0.034602978187439785
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 4.82 seconds. Users per second: 997
# Recommender MAP is= 0.01751332621476734
# Hybrid2 Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 6.19 seconds. Users per second: 783
# Recommender MAP is= 0.03458330280070702
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 5.68 seconds. Users per second: 846
# Recommender MAP is= 0.017339750106177047
# Hybrid3 Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 3.98 seconds. Users per second: 1218
# Recommender MAP is= 0.03502607889048534
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 7.22 seconds. Users per second: 665
# Recommender MAP is= 0.017264967130323466

# %%
hybrid4=ItemKNNScoresHybridRecommender(URM_train,superSlim,UCFRecommender)
hybrid4.fit(alpha=0.8)
hybrid5=ItemKNNSimilarityHybridRecommender3(URM_train,SLIMrecommender, CFrecommender,CBFrecommender)
hybrid5.fit(topK=800, alpha=0.7, beta=0.5, gamma=0.2)

print("Hybrid4 Recommender")
result = hybrid4.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = hybrid4.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))

print("Hybrid5 Recommender")
result = hybrid5.evaluateRecommendations(URM_test_sequential)
print("Recommender MAP is= {}".format(result["MAP"]))
result = hybrid5.evaluateRecommendations(URM_test_random)
print("Recommender MAP is= {}".format(result["MAP"]))
# Out:
# Hybrid4 Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 4.91 seconds. Users per second: 987
# Recommender MAP is= 0.033450984214658176
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 4.59 seconds. Users per second: 1048
# Recommender MAP is= 0.016972421368057204
# Hybrid5 Recommender
# SequentialEvaluator: Processed 4848 ( 100.00% ) in 3.90 seconds. Users per second: 1243
# Recommender MAP is= 0.03399108454460803
# SequentialEvaluator: Processed 4807 ( 100.00% ) in 3.87 seconds. Users per second: 1243
# Recommender MAP is= 0.01718322027437209
